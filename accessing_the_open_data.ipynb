# %% [markdown]
# # PORTO CITY DATA
#
#
# All the city data from Porto is indexed at Porto's CKAN platform: https://opendata.porto.hackacity.eu/.
#
# All the data is downloadable from the CKAN platform directly in various formats (CSV, images, etc...). The exception is the IoT data, which is available from a separate API endpoint, but which is indexed by CKAN.

# %% [markdown]
# # The CKAN Platform
#
# CKAN is a tool for making open data websites. (Think of a content management system like WordPress - but for data, instead of pages and blog posts). It helps you manage and publish collections of data.
#
# Once your data is published, users can use its faceted search features to browse and find the data they need, and preview it using maps, graphs and tables - whether they are developers, journalists, researchers, NGOs, citizens, or even your own staff.
#
# **Datasets and resources**
#
# For CKAN purposes, data is published in units called “datasets”. A dataset is a parcel of data - for example, it could be the crime statistics for a region, the spending figures for a government department, or temperature readings from various weather stations. When users search for data, the search results they see will be individual datasets.
#
# A dataset contains two things:
#
# * ***Metadata***: Information about the data.
# For example, the title and publisher, date, what formats it is available in, what license it is released under, etc.
# * ***Resources***: The data itself. CKAN does not mind what format the data is in. A resource can be a CSV or Excel spreadsheet, XML file, PDF document, image file, linked data in RDF format, etc. CKAN can store the resource internally, or store it simply as a link, the resource itself being elsewhere on the web.
#
# Note: On early CKAN versions, datasets were called “packages” and this name has stuck in some places, specially internally and on API calls. Package has exactly the same meaning as “dataset”.
#
# **API documentation**
# * CKAN: https://docs.ckan.org/en/2.8/api/
#
# **API endpoints**
# * CKAN: https://opendata.porto.hackacity.eu/api/3/

# %% [markdown]
# ## Available Data Sets & Resources
#
# Bellow you can find the API call which lists all available datasets.

# %%
## Porto's CKAN Platform examples
## Show all the datasets available (aka packages)

import pprint
import requests
url = "https://opendata.porto.hackacity.eu/api/3/action/package_list";
r = requests.get(url)
pprint.pprint(r.json())
# Out:
# {'help': 'https://opendata.porto.hackacity.eu/api/3/action/help_show?name=package_list',
#  'result': ['agua-de-nascente',
#             'alojamento-local',
#             'alojamentos-hoteleiros-2011',
#             'areas-edificadas',
#             'areas-verdes',
#             'atlas-desportivo',
#             'bairros-de-casas-economicas-do-estado-novo',
#             'balizas-de-sinalizacao',
#             'bicicletarios',
#             'carta-de-patrimonio',
#             'cemiterios-municipais-ou-privados-2007',
#             'centros-de-saude-e-extensoes-2001',
#             'ciclovias',
#             'correios-2013',
#             'dissuasores-de-controlo-de-acessos',
#             'ecocentros-2006',
#             'edificios-de-interesse-publico',
#             'edificios-de-interesse-publico-2012',
#             'eixos-de-via-infraestruturas-portugal',
#             'envolvente',
#             'equipamentos-de-recolha-contentores-cinzentos_-cones_recolha-de-objectos-fora-de-uso_-reee-e-vidroes',
#             'equipamentos-de-saude',
#             'espacos-verdes-com-valor-patrimonial-2012',
#             'estabelecimentos-de-bebidas-e-restauracao-da-movida-2012',
#             'estabelecimentos-de-ensino-por-ano-letivo',
#             'estabelecimentos-de-ensino-superior-por-ano-letivo',
#             'feiras-e-mercados-2011',
#             'fontes-de-contaminacao-cemiterios-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-cemiterios-carta-hidrogeologica',
#             'fontes-de-contaminacao-depositos-de-lixo-misto-aterrados-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-depositos-de-lixo-misto-aterrados-carta-hidrogeologica',
#             'fontes-de-contaminacao-entulheiras-aterradas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-entulheiras-aterradas-carta-hidrogeologica',
#             'fontes-de-contaminacao-entulheiras-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-entulheiras-carta-hidrogeologica',
#             'fontes-de-contaminacao-lixeiras-aterradas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-lixeiras-aterradas-carta-hidrogeologica',
#             'fontes-de-contaminacao-sucatas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-sucatas-carta-hidrogeologica',
#             'furos-de-captacao-de-agua',
#             'georisk-carta-de-ocorrencias',
#             'georisk-carta-de-vulnerabilidade',
#             'hoteis_-aparthoteis-e-albergarias-centroides',
#             'limites-de-freguesias-1956',
#             'limites-de-freguesias-pos-reforma-da-lei-no-11-a-2013',
#             'metro-do-porto',
#             'nascentes',
#             'parcometros-zonas-de-estacionamento-pago',
#             'parques-de-estacionamento-municipais',
#             'parques-de-motociclos',
#             'patrimonio-mundial',
#             'pensoes_-residenciais-e-hospedarias-centroides',
#             'piscinas-centroides',
#             'pocos',
#             'porto-meteorologia',
#             'porto-niveis-de-ruido',
#             'porto-pontos-de-acesso-wifi-apd',
#             'porto-pontos-de-interesse',
#             'porto-qualidade-do-ar',
#             'porto-transito',
#             'porto-veiculos-do-municipio',
#             'postos-de-abastecimento-de-combustiveis-centroides',
#             'postos-de-informacao-turistica-centroides',
#             'praca-de-taxis',
#             'processos-de-fiscalizacao-ambito-do-dep-municipal-de-fiscalizacao',
#             'promocao-do-vinho-do-porto-centroides',
#             'quiosques-multimedia-centroides',
#             'recintos-musicais-centroides',
#             'recintos-polidesportivos-centroides',
#             'reparticoes-de-financas-e-tesourarias-servicos-centroides',
#             'restaurantes-centroides',
#             'ruido-zona-mista',
#             'ruido-zona-mista-2012',
#             'ruido-zona-sensivel',
#             'ruido-zona-sensivel-2012',
#             'sinalizacao-led-em-travessias-de-peoes',
#             'stcp-autocarros-paragens-centroides',
#             'superficies-comerciais-distribuicao-centroides',
#             'supermercados-e-hipermercados',
#             'teatros-centroides',
#             'templos-religiosos-centroides',
#             'transito_-impedimentos-e-obras-online',
#             'transportes-publicos-stcp',
#             'transportes-publicos-stcp-linhas',
#             'transportes-publicos-stcp-paragens',
#             'tribunais-centroides',
#             'zona-de-recolha-de-residuos',
#             'zonas-de-comercio-tradicional-centroides',
#             'zonas-instaveis-mais-criticas',
#             'zonas-instaveis-menos-criticas',
#             'zonas-potencialmente-instaveis'],
#  'success': True}

# %% [markdown]
# ## Resource
#
# You can find all kind of information regarding a dataset. Each dataset can have multiple resources, which can be accessed through the respective URL.

# %%
## Porto's CKAN Platform examples
## In this example we look at the parking zones in the city

import pprint
import requests
url = "https://opendata.porto.hackacity.eu/api/3/action/package_show?id=transportes-publicos-stcp";
r = requests.get(url)
j = r.json()
print("Resources: ")
for resource in j['result']['resources']:
  print("{}({}):".format(resource['name'], resource['format']))
  print(resource['url'] + "\n")
print("Full resource information: ")
pprint.pprint(j)
# Out:
# Resources:
# STCP-Autocarros-Paragens(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/3
#
# STCP-Autocarros-Rede(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/2
#
# Full resource information:
# {'help': 'https://opendata.porto.hackacity.eu/api/3/action/help_show?name=package_show',
#  'result': {'author': None,
#             'author_email': None,
#             'creator_user_id': 'cbdf7f56-3822-4c49-8660-490e14bd313e',
#             'extras': [],
#             'groups': [{'description': 'Infraestruturas e mobilidade',
#                         'display_name': 'Infraestruturas e mobilidade',
#                         'id': '3d35a8ba-4899-4bb3-ad27-428888afb540',
#                         'image_display_url': '',
#                         'name': 'infraestruturas-e-mobilidade',
#                         'title': 'Infraestruturas e mobilidade'}],
#             'id': '6c040ba8-e6ea-49da-bbe0-58467853fbe9',
#             'isopen': False,
#             'license_id': None,
#             'license_title': None,
#             'maintainer': None,
#             'maintainer_email': None,
#             'metadata_created': '2019-04-01T11:11:42.313824',
#             'metadata_modified': '2019-04-01T11:11:42.807351',
#             'name': 'transportes-publicos-stcp',
#             'notes': 'Transportes Públicos (STCP)',
#             'num_resources': 2,
#             'num_tags': 3,
#             'organization': {'approval_status': 'approved',
#                              'created': '2019-03-30T09:17:27.327033',
#                              'description': '',
#                              'id': 'b1a18a2a-1efb-4f6a-953d-3a916fc36bac',
#                              'image_url': '',
#                              'is_organization': True,
#                              'name': 'cmporto',
#                              'revision_id': '185f8cdd-e79b-418d-a152-f2bd210b389f',
#                              'state': 'active',
#                              'title': 'C. M. Porto',
#                              'type': 'organization'},
#             'owner_org': 'b1a18a2a-1efb-4f6a-953d-3a916fc36bac',
#             'private': False,
#             'relationships_as_object': [],
#             'relationships_as_subject': [],
#             'resources': [{'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-04-01T11:11:42.523146',
#                            'datastore_active': False,
#                            'description': 'STCP-Autocarros-Paragens',
#                            'entity': [],
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '1b57e599-e690-4841-be30-cb8afe0f62cc',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'STCP-Autocarros-Paragens',
#                            'package_id': '6c040ba8-e6ea-49da-bbe0-58467853fbe9',
#                            'position': 0,
#                            'resource_type': None,
#                            'revision_id': '740c28a7-e03f-4355-871a-1f88787c36fa',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/3',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-04-01T11:11:42.827610',
#                            'datastore_active': False,
#                            'description': 'STCP-Autocarros-Rede',
#                            'entity': [],
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': 'd88355fd-9f56-4e87-915b-8f48a3c52a8e',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'STCP-Autocarros-Rede',
#                            'package_id': '6c040ba8-e6ea-49da-bbe0-58467853fbe9',
#                            'position': 1,
#                            'resource_type': None,
#                            'revision_id': '740c28a7-e03f-4355-871a-1f88787c36fa',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/2',
#                            'url_type': None}],
#             'revision_id': '51711fe5-d435-4e76-bd62-9c14b4367bbc',
#             'state': 'active',
#             'tags': [{'display_name': 'SIG',
#                       'id': 'cfdfb79d-db80-49b2-8d9b-f0ac69df3fda',
#                       'name': 'SIG',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'apd-auto-load',
#                       'id': 'd0db0fd7-5f2b-418a-b885-0c4199bdf622',
#                       'name': 'apd-auto-load',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'dmevgi',
#                       'id': '73e00f22-6e01-4569-a7b0-e814712dc2fd',
#                       'name': 'dmevgi',
#                       'state': 'active',
#                       'vocabulary_id': None}],
#             'title': 'Transportes Públicos (STCP)',
#             'type': 'dataset',
#             'url': None,
#             'version': None},
#  'success': True}

# %%
## Example of an API enpoint indexed by CKAN

import requests
url = "https://opendata.porto.hackacity.eu/api/3/action/package_show?id=porto-meteorologia"
r = requests.get(url)
j = r.json()
for resource in j['result']['resources']:
  print("{}({}):".format(resource['name'], resource['format']))
  print(resource['url'] + "\n")
# Out:
# PORTO Meteorologia - Valores observados(fiware-ngsi):
# https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherObserved
#
# PORTO Meteorologia - Previsão(fiware-ngsi):
# https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherForecast

# %% [markdown]
# # IoT Data
#
# A special resource is the information from the IoT platform, which is accessible through the NGSI API. The historical data for each is available at a seperate endpoint. The data structure for each API access point is available through the NGSI API (see below).
#
# **Types**: Are types of devices or data \\
# **Entities**: Each entity is a device of a certain type
#
# **API documentation**
# * NGIS: https://fiware-orion.readthedocs.io/en/2.0.0/user/walkthrough_apiv2/#query-entity
# * Data format: https://gitlab.com/synchronicity-iot/synchronicity-data-models/
# * Historical data: http://history-data.urbanplatform.portodigital.pt/v2/ui/
#
# **API endpoints**
# * Live Data:  https://broker.fiware.urbanplatform.portodigital.pt/v2/
# * Historical Data: http://history-data.urbanplatform.portodigital.pt/v2/

# %%
## List of all IoT resources with the respective data type

import requests
import json

url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/types"
r = requests.get(url)
j = r.json()

for item in j:
  print("{} ({}):".format(item["type"], item["count"]))
  attrs = item['attrs']
  print("{:<30} {:<15}".format('Name','Types'))
  for k, v in attrs.items():
    print("{:<30} {:<15}".format(k, ", ".join(v['types'])))
  print("")
# Out:
# AirQualityObserved (5):
# Name                           Types
# CO                             Number
# NO2                            Number
# O3                             Number
# Ox                             Number
# PM1                            Number
# PM10                           Number
# PM25                           Number
# dateObserved                   DateTime
# location                       geo:json
#
# ArrivalEstimation (8):
# Name                           Types
# dateModified                   DateTime
# description                    Text
# headSign                       StructuredValue
# remainingTime                  StructuredValue
#
# Device (191):
# Name                           Types
# category                       StructuredValue
# configuration                  StructuredValue
# controlledAsset                StructuredValue
# controlledProperty             StructuredValue
# dateExpires                    DateTime
# dateModified                   DateTime
# description                    None, Text
# l_serialNumber                 None, Text
# location                       None, geo:json
# name                           Text
# owner                          StructuredValue
# value                          Text
#
# Event (6202):
# Name                           Types
# address                        StructuredValue
# dateModified                   Text
# description                    Text
# description_es                 Text
# description_pt                 Text
# discounts                      Text
# discounts_es                   Text
# discounts_pt                   Text
# endDate                        StructuredValue, Text
# informationUrl                 Text
# informationUrl_es              Text
# informationUrl_pt              Text
# location                       Text, geo:json
# multimedia                     StructuredValue, Text
# name                           Text
# name_es                        Text
# name_pt                        Text
# observations                   Text
# observations_es                Text
# observations_pt                Text
# promoter                       Text
# promoter_es                    Text
# promoter_pt                    Text
# reservationUrl                 Text
# reservationUrl_es              Text
# reservationUrl_pt              Text
# schedule                       Text
# schedule_es                    Text
# schedule_pt                    Text
# specifications                 Text
# specifications_es              Text
# specifications_pt              Text
# startDate                      Text
# target                         Text
# target_es                      Text
# target_pt                      Text
# theme                          StructuredValue, Text
# theme_es                       StructuredValue, Text
# theme_pt                       StructuredValue, Text
#
# GtfsTransitFeedFile (1):
# Name                           Types
# description                    Text
# endDate                        Text
# feedFileURL                    Text
# publisher                      StructuredValue
# startDate                      Text
# version                        StructuredValue
#
# NoiseLevelObserved (15):
# Name                           Types
# LAeq                           Number
# dateObserved                   DateTime
# dateObservedFrom               DateTime
# dateObservedTo                 DateTime
# location                       geo:json
# measurand                      StructuredValue
#
# OffStreetParking (1):
# Name                           Types
# allowedVehicleType             StructuredValue
# availableSpotNumber            Number
# category                       StructuredValue
# chargeType                     StructuredValue
# location                       StructuredValue
# name                           Text
# occupancyDetectionType         StructuredValue
# requiredPermit                 StructuredValue
# totalSpotNumber                Number
#
# PointOfInterest (3060):
# Name                           Types
# accessibility                  None, StructuredValue, Text
# accessibility_es               None, StructuredValue, Text
# accessibility_pt               None, StructuredValue, Text
# address                        StructuredValue
# category                       StructuredValue
# closedOnHoliday                Text
# contactPoint                   StructuredValue
# costDescription                Text
# costDescription_es             Text
# costDescription_pt             Text
# dateModified                   DateTime, Text
# description                    None, Text
# description_es                 None, Text
# description_pt                 None, Text
# internetAccess                 None, Text
# internetWireless               None, Text
# location                       StructuredValue, Text, geo:json
# multimedia                     StructuredValue
# name                           Text
# name_es                        Text
# name_pt                        Text
# openingHoursSpecification      StructuredValue
# smokingArea                    None, Text
# socialNetwork                  StructuredValue, Text
# tag                            None, StructuredValue, Text
# tag_es                         None, StructuredValue, Text
# tag_pt                         None, StructuredValue, Text
# target                         StructuredValue, Text
# target_es                      StructuredValue, Text
# target_pt                      StructuredValue, Text
# touristic                      Text
# wifi                           None, Text
#
# TrafficFlowObserved (115):
# Name                           Types
# dateModified                   DateTime, Text
# dateObserved                   Text
# dateObservedFrom               DateTime, Text
# dateObservedTo                 DateTime, Text
# intensity                      Number
# laneId                         Number
# location                       geo:json
#
# Vehicle (246):
# Name                           Types
# category                       StructuredValue
# dateModified                   DateTime, Text
# latitude                       Number
# location                       geo:json
# longitude                      Number
# speed                          Number
# vehicleType                    Text
#
# WeatherForecast (131):
# Name                           Types
# address                        PostalAddress
# dataProvider                   Text
# dateIssued                     DateTime
# dateRetrieved                  DateTime
# dayMaximum                     StructuredValue
# dayMinimum                     StructuredValue
# feelsLikeTemperature           None, Number
# location                       geo:json
# precipitationProbability       None, Number
# relativeHumidity               None, Number
# source                         URL
# temperature                    None, Number
# validFrom                      DateTime
# validTo                        DateTime
# validity                       Text
# weatherType                    Text
# windDirection                  Number
# windSpeed                      None, Number
#
# WeatherObserved (17):
# Name                           Types
# PM1                            Number
# PM10                           Number
# PM25                           Number
# barometricPressure             Float, Number
# dataProvider                   String
# dateObserved                   DateTime
# dewPoint                       Number
# location                       geo:json
# name                           String
# precipitation                  Float
# relativeHumidity               Number
# solarRadiation                 Number
# source                         url
# temperature                    Number
# windDirection                  Float, Number
# windSpeed                      Float, Number
#
# gtfsAgency (1):
# Name                           Types
# language                       Text
# name                           Text
# page                           Text
# timezone                       Text
#
# gtfsCalendarDateRule (6):
# Name                           Types
# appliesOn                      Text
# exceptionType                  Text
# hasService                     Text
#
# gtfsCalendarRule (15):
# Name                           Types
# endDate                        Text
# friday                         Boolean
# hasService                     Text
# monday                         Boolean
# saturday                       Boolean
# startDate                      Text
# sunday                         Boolean
# thursday                       Boolean
# tuesday                        Boolean
# wednesday                      Boolean
#
# gtfsRoute (73):
# Name                           Types
# description                    Text
# name                           Text
# page                           Text
# routeColor                     Text
# routeID                        Text
# routeTextColor                 Text
# routeType                      Text
# shortName                      Text
#
# gtfsService (15):
# Name                           Types
# code                           Text
# operatedBy                     Text
#
# gtfsStop (2468):
# Name                           Types
# code                           Text
# location                       geo:json
# name                           Text
# page                           Text
# zoneCode                       Text

# %% [markdown]
# ## Accessing Live Value
# All the live value are available through the FiWare broker, as described in the documentation of the link on top. The example below ilustrates how to access all entities (an entity is a single sensor) of a certain type.

# %%
## You can access live values through the fiware broker

import requests
import pprint
url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=AirQualityObserved"
r = requests.get(url)
j = r.json()
pprint.pprint(j)
# Out:
# [{'CO': {'metadata': {}, 'type': 'Number', 'value': 760.9},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 122.4},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 8.8},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 133.6},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 0},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 0},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 0},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:21.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.684325, 41.1735278],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 770.9},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 81.1},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 28.1},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 111.9},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 3.8},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 5.2},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 3.8},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:26.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b97a1bde521e3053085c08c',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.605194, 41.180222],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 628.3},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 68.9},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 63.4},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 135.3},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 4.8},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 5.9},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 4.3},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:04:27.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b632f2706599b05e998bed8',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6721462, 41.165162],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 732.6},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 100.8},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 35.4},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 140},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 4.6},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 6.2},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 4.6},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:18.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b72dbfa06599b05e9a74f27',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.5907964, 41.1625965],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 595.5},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 54.5},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 45.4},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 102.3},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 5.9},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 7.5},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 5},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:23.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b97a1a6e521e3053085c067',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6131861, 41.1718621],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'}]

# %% [markdown]
# ### Georeferenced Queries
# You can also do Georeferenced queries (check documentation here: http://telefonicaid.github.io/fiware-orion/api/v2/stable/)

# %%
## We are going to find all the points of interests within 150 meters radius of Alfandega.

import requests
import pprint
url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=PointOfInterest&georel=near;maxDistance:150&geometry=point&coords=41.143347472409914,-8.621363679260412"
r = requests.get(url)
j = r.json()
#pprint.pprint(j)
for poi in j:
  print(poi['name']['value'])
  
  if (poi['description']['value'] is not None):
    print(poi['description']['value'])
    
  if (poi['description']['value'] is not None):
    print("Multimedia:")
    for mm in poi['multimedia']['value']:
      print(mm['url'])
  print("")
# Out:
# Alfândega filmes, Lda
#
# Alfândega Nova do Porto
# A neoclassical building, built in the 19th century, according to a project carried out by the engineer Jean F. G. Colson. It has two facades, one facing the Douro river and one facing the city. Note the structural solutions that resorted to the use of iron in conjunction with other materials - stone, brick or wood - depending on the functionality of the different spaces. In 1987, it was decided to house the future Museum of Transport and Communications, in the building belonging to the Association with the same name. For this, restoration and adaptation works were carried out, according to the project by the architect Eduardo Souto Moura. The Association for the Transport and Communications Museum  Associação para o Museu dos Transportes e Comunicações-A.M.T.C  also manages a Congress Centre, spread across various areas in the Building of Alfândega Nova do Porto.
# Multimedia:
# http://recursos.visitporto.travel/pois/2059_6.jpg
# http://recursos.visitporto.travel/pois/2059_5.jpg
# http://recursos.visitporto.travel/pois/2059_4.jpg
# http://recursos.visitporto.travel/pois/2059_3.jpg
# http://recursos.visitporto.travel/pois/2059_2.jpg
# http://recursos.visitporto.travel/pois/2059_1.jpg
#
# Armazéns da Companhia
# First warehouse belonging to the General Company for the Agriculture of the Upper Douro Vineyards, it was founded in 1756 by Marquês de Pombal. It was the first regulating body for the production and sale of Douro Wines. Part of the Urban Wine Route.
# Multimedia:
# http://recursos.visitporto.travel/pois/2072_1.jpg
# http://recursos.visitporto.travel/pois/2072_2.jpg
# http://recursos.visitporto.travel/pois/2072_3.jpg
#
# Associação Náutica Desportiva e Cultural  Portus Cale
# Association dedicated to sports, cultural and civic education, having as motto to educate through sports. The practiced modalities are rowing and canoeing. This is the only federate rowing club of the city renting canoes.
# Multimedia:
#
# Bandeirinha da Saúde
# Granite pyramid topped by an artistic forged iron pinnacle. It was used to hoist the  bandeirinha da saúde    small flag of health  , which set the mooring limits in times of plague.
# Multimedia:
# http://recursos.visitporto.travel/pois/825_2.jpg
# http://recursos.visitporto.travel/pois/825_1.jpg
# http://recursos.visitporto.travel/pois/825_6.jpg
# http://recursos.visitporto.travel/pois/825_5.jpg
# http://recursos.visitporto.travel/pois/825_4.jpg
# http://recursos.visitporto.travel/pois/825_8.jpg
# http://recursos.visitporto.travel/pois/825_3.jpg
# http://recursos.visitporto.travel/pois/825_7.jpg
#
# Library of the Porto Customs Museum
# Opened in 2006, its main objective was to provide and make accessible to all interested users, all information and  resources regarding Customs from the Directorate General of Customs  DGAIEC , of transport and communications. br   It continues to provide the following services: face-to-face consultation, user support and guidance, reproduction of documents  photocopying and scanning , home loan  transport and communications issues , use of personal computer equipment and use of the space as a study area.
# Multimedia:
# http://recursos.visitporto.travel/pois/1809_1.jpg
#
# Centro de Congressos da Alfândega do Porto
# Its vicinity to the river Douro and to the historical centre, the building’s unique dimension and architecture  arch. Eduardo Souto de Moura , are attributes that turn this space in the ideal spot for corporative, scientific, cultural and commercial events. The building has an adaptable area of 50.000 square metres with 22 multifunctional rooms, being 3 of them equipped with translating booth and wi-fi covering the whole area. The boarding deck and the parking lot with 400 places are relevant areas as well as the existence of cultural and museum spaces.
# Multimedia:
# http://recursos.visitporto.travel/pois/2171_1.jpg
# http://recursos.visitporto.travel/pois/2171_2.jpg
# http://recursos.visitporto.travel/pois/2171_3.jpg
# http://recursos.visitporto.travel/pois/2171_4.jpg
# http://recursos.visitporto.travel/pois/2171_5.jpg
# http://recursos.visitporto.travel/pois/2171_6.jpg
# http://recursos.visitporto.travel/pois/2171_7.jpg
# http://recursos.visitporto.travel/pois/2171_8.jpg
#
# Colher  Spoon  Fountain
# The Colher  Spoon  Fountain owes its name to the tax on goods paid to the bishop of Porto, also known as “colher  spoon ”. This fountain is adjoined to the last house in the street of Miragaia and is supposed to be one of the oldest as revealed by the inscription on the granite front, dated from 1629.  It consists of a single spout of which its water was believed to be some of the best in the city.
# Multimedia:
# http://recursos.visitporto.travel/pois/1339_1.jpg
# http://recursos.visitporto.travel/pois/1339_2.jpg
# http://recursos.visitporto.travel/pois/1339_3.jpg
# http://recursos.visitporto.travel/pois/1339_4.jpg
#
# DouroAzul
# Established in 1993, DouroAzul is the leading river cruise company in the Douro River, a reference name in quality, competence and personality. Offering luxury cruises in hotelship and on board of the royal barge Spirit of Chartwell, it offers as well city sightseeing tours on board of the BlueBus City Tours and the BlueBoats, both providing audio guide service in  16 languages,  helicopter tours, and tours on private yacht. The Douro Azul Welcome Tourist & Business Center, is a multipurpose space for several sorts of events.  DouroAzul has been working throughout the years to offer its clients the best of the Douro Valley, always committed to present a high quality service, combined with the true Portuguese charm.
# Multimedia:
# http://recursos.visitporto.travel/pois/1822_4.jpg
# http://recursos.visitporto.travel/pois/1822_3.jpg
# http://recursos.visitporto.travel/pois/1822_2.jpg
# http://recursos.visitporto.travel/pois/1822_1.jpg
# http://recursos.visitporto.travel/pois/1822_8.jpg
# http://recursos.visitporto.travel/pois/1822_7.jpg
# http://recursos.visitporto.travel/pois/1822_6.jpg
# http://recursos.visitporto.travel/pois/1822_5.jpg
#
# DouroAzul
# Established in 1993, DouroAzul is the leading river cruise company in the Douro River, a reference name in quality, competence and personality. Offering luxury cruises in hotelship and on board of the royal barge Spirit of Chartwell, it offers as well city sightseeing tours on board of the BlueBus City Tours and the BlueBoats, both providing audio guide service in  16 languages,  helicopter tours, and tours on private yacht. The Douro Azul Welcome Tourist & Business Center, is a multipurpose space for several sorts of events.  DouroAzul has been working throughout the years to offer its clients the best of the Douro Valley, always committed to present a high quality service, combined with the true Portuguese charm.
# Multimedia:
# http://recursos.visitporto.travel/pois/1888_7.jpg
# http://recursos.visitporto.travel/pois/1888_6.jpg
# http://recursos.visitporto.travel/pois/1888_5.jpg
# http://recursos.visitporto.travel/pois/1888_4.jpg
# http://recursos.visitporto.travel/pois/1888_3.jpg
# http://recursos.visitporto.travel/pois/1888_2.jpg
# http://recursos.visitporto.travel/pois/1888_1.jpg
#
# DouroAzul
# Established in 1993, DouroAzul is the leading river cruise company in the Douro River, a reference name in quality, competence and personality. Offering luxury cruises in hotelship and on board of the royal barge Spirit of Chartwell, it offers as well city sightseeing tours on board of the BlueBus City Tours and the BlueBoats, both providing audio guide service in  16 languages,  helicopter tours, and tours on private yacht. The Douro Azul Welcome Tourist & Business Center, is a multipurpose space for several sorts of events.  DouroAzul has been working throughout the years to offer its clients the best of the Douro Valley, always committed to present a high quality service, combined with the true Portuguese charm.
# Multimedia:
# http://recursos.visitporto.travel/pois/2214_7.jpg
# http://recursos.visitporto.travel/pois/2214_6.jpg
# http://recursos.visitporto.travel/pois/2214_5.jpg
# http://recursos.visitporto.travel/pois/2214_4.jpg
# http://recursos.visitporto.travel/pois/2214_3.jpg
# http://recursos.visitporto.travel/pois/2214_2.jpg
# http://recursos.visitporto.travel/pois/2214_1.jpg
#
# Douro River Cozy Apartments
# The Douro River Apartments, each one with its own style, are housed in a building that has won awards for the way it has been renovated.  These self-sufficient lodgings offer views of the Douro River and are just a few metres from the World of Discoveries Museum.  Both apartments have a living-room and a fully equipped kitchen. The building itself is amazingly light and airy. The distinctive architecture of the building, the amenities in the apartments and the riverside setting all make this the perfect alternative for your stay in Porto.
# Multimedia:
# http://recursos.visitporto.travel/pois/3583_8.jpg
# http://recursos.visitporto.travel/pois/3583_7.jpg
# http://recursos.visitporto.travel/pois/3583_6.jpg
# http://recursos.visitporto.travel/pois/3583_5.jpg
# http://recursos.visitporto.travel/pois/3583_4.jpg
# http://recursos.visitporto.travel/pois/3583_3.jpg
# http://recursos.visitporto.travel/pois/3583_2.jpg
# http://recursos.visitporto.travel/pois/3583_1.jpg
#
# Church of S. Pedro de Miragaia
# Known for being one of the most ancient churches in the city, the temple went through deep architectonic changes in the 1830s. From the crossing, the chancel is totally covered with wood carvings, showing artistic expressions from different times: National, in the style of D. João V, and Rococo. Worthy of notice and of great artistic value is the triptych of Flemish origin having as subject the Pentecost.
# Multimedia:
# http://recursos.visitporto.travel/pois/976_1.jpg
#
# Jorge Neves, Produção Audiovisual
#
# Transports and Communications Museum
# To visit the Museum is to let yourself be taken by unique atmospheres and striking experiences. br  The exhibition “The engine of the Republic: the Presidential cars” reveals the important collection of vehicles that served the Presidency of the Republic from 1910 to the present day. “Metamorfose de um Lugar: Museu das Alfândegas”  metamorphosis of a place: the customs’ museum  is a travel through the history of customs and its relation to Porto. br  The visit to the building unveils over 160 years since the beginning of its construction in the old Miragaia Beach.
# Multimedia:
# http://recursos.visitporto.travel/pois/787_8.jpg
# http://recursos.visitporto.travel/pois/787_7.jpg
# http://recursos.visitporto.travel/pois/787_6.jpg
# http://recursos.visitporto.travel/pois/787_5.jpg
# http://recursos.visitporto.travel/pois/787_4.jpg
# http://recursos.visitporto.travel/pois/787_2.jpg
# http://recursos.visitporto.travel/pois/787_1.jpg
# http://recursos.visitporto.travel/pois/787_3.jpg
#
# World of Discoveries - Interactive Museum and Theme Park
# In the city that saw the birth of “nce Henry , embark on “the discovery of wonderful things never seen before”. The World of Discoveries is an Interactive Museum and Theme Park that reconstructs the fantastic odyssey of the Portuguese navigators, crossing the oceans to the discovery of a world until then unknown. This meeting place of cultures proposes to honour this period and those brave ones that introduced the notion of globalization. It’s the cultural complement that will forever change your city experience.
# Multimedia:
# http://recursos.visitporto.travel/pois/3450_8.jpg
# http://recursos.visitporto.travel/pois/3450_7.jpg
# http://recursos.visitporto.travel/pois/3450_6.jpg
# http://recursos.visitporto.travel/pois/3450_5.jpg
# http://recursos.visitporto.travel/pois/3450_4.jpg
# http://recursos.visitporto.travel/pois/3450_3.jpg
# http://recursos.visitporto.travel/pois/3450_2.jpg
# http://recursos.visitporto.travel/pois/3450_1.jpg
#
# World of Discoveries – Museu Interativo & Parque Temático
# World of Discoveries  provides a Theme Restaurant for 150 people and an 200 m2 Events Room available for organizing corporative events, conferences and other kind of events, for groups not exceeding 100 people. Upon request we can also provide suggestions and organize events and/or theme dinners. Turn-key offers.
# Multimedia:
# http://recursos.visitporto.travel/pois/3451_8.jpg
# http://recursos.visitporto.travel/pois/3451_7.jpg
# http://recursos.visitporto.travel/pois/3451_6.jpg
# http://recursos.visitporto.travel/pois/3451_5.jpg
# http://recursos.visitporto.travel/pois/3451_4.jpg
# http://recursos.visitporto.travel/pois/3451_3.jpg
# http://recursos.visitporto.travel/pois/3451_2.jpg
# http://recursos.visitporto.travel/pois/3451_1.jpg

# %% [markdown]
# ## Accessing historical values
# The historical values are accessible through the documentation described above. Because the query is quite heavy, you can only access one entity at once. \\
# In the example below we took the id of the first entity of the query above. \\
# Please note: The API automatically limits the number of records, and you will need to query more using the starting and ending date (see the full documentation on the link above).

# %%
## Example of IoT Resource - Air Quality

import requests
import pprint
# First let's the ID's from the FiWare
url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=AirQualityObserved"
r = requests.get(url)
j = r.json()
print("Available sensores:")
for sensor in j: 
  print(sensor['id'])
print("")

# Get the historical data of one of the sensors
url = "http://history-data.urbanplatform.portodigital.pt/v2/entities/urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54?limit=20"
r = requests.get(url)
j = r.json()
pprint.pprint(j)
# Out:
# Available sensores:
# urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54
# urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b97a1bde521e3053085c08c
# urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b632f2706599b05e998bed8
# urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b72dbfa06599b05e9a74f27
# urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b97a1a6e521e3053085c067
#
# {'data': {'attributes': [{'attrName': 'CO',
#                           'values': [461.7,
#                                      461.7,
#                                      353.2,
#                                      353.2,
#                                      353.2,
#                                      446.0,
#                                      446.0,
#                                      446.0,
#                                      355.0,
#                                      355.0,
#                                      355.0,
#                                      419.3,
#                                      419.3,
#                                      419.3,
#                                      293.4,
#                                      293.4,
#                                      293.4,
#                                      359.1,
#                                      359.1,
#                                      359.1]},
#                          {'attrName': 'NO2',
#                           'values': [110.2,
#                                      110.2,
#                                      97.3,
#                                      97.3,
#                                      97.3,
#                                      83.5,
#                                      83.5,
#                                      83.5,
#                                      85.7,
#                                      85.7,
#                                      85.7,
#                                      87.6,
#                                      87.6,
#                                      87.6,
#                                      64.5,
#                                      64.5,
#                                      64.5,
#                                      69.7,
#                                      69.7,
#                                      69.7]},
#                          {'attrName': 'O3',
#                           'values': [6.8,
#                                      6.8,
#                                      12.3,
#                                      12.3,
#                                      12.3,
#                                      20.1,
#                                      20.1,
#                                      20.1,
#                                      20.0,
#                                      20.0,
#                                      20.0,
#                                      21.1,
#                                      21.1,
#                                      21.1,
#                                      31.7,
#                                      31.7,
#                                      31.7,
#                                      29.1,
#                                      29.1,
#                                      29.1]},
#                          {'attrName': 'Ox',
#                           'values': [120.8,
#                                      120.8,
#                                      112.8,
#                                      112.8,
#                                      112.8,
#                                      107.2,
#                                      107.2,
#                                      107.2,
#                                      109.4,
#                                      109.4,
#                                      109.4,
#                                      112.5,
#                                      112.5,
#                                      112.5,
#                                      99.0,
#                                      99.0,
#                                      99.0,
#                                      101.8,
#                                      101.8,
#                                      101.8]},
#                          {'attrName': 'PM1',
#                           'values': [20.0,
#                                      19.8,
#                                      22.2,
#                                      22.8,
#                                      21.6,
#                                      19.2,
#                                      18.8,
#                                      18.4,
#                                      16.8,
#                                      18.6,
#                                      17.8,
#                                      15.6,
#                                      18.8,
#                                      19.0,
#                                      18.8,
#                                      17.8,
#                                      16.8,
#                                      16.6,
#                                      16.2,
#                                      17.0]},
#                          {'attrName': 'PM10',
#                           'values': [67.3,
#                                      70.4,
#                                      69.5,
#                                      73.7,
#                                      83.6,
#                                      60.5,
#                                      66.0,
#                                      66.0,
#                                      59.4,
#                                      58.5,
#                                      64.9,
#                                      52.8,
#                                      74.8,
#                                      74.4,
#                                      61.0,
#                                      61.6,
#                                      51.1,
#                                      63.4,
#                                      60.0,
#                                      50.6]},
#                          {'attrName': 'PM25',
#                           'values': [50.0,
#                                      49.5,
#                                      54.4,
#                                      56.0,
#                                      53.6,
#                                      48.5,
#                                      47.0,
#                                      45.6,
#                                      42.4,
#                                      45.6,
#                                      45.0,
#                                      39.6,
#                                      46.0,
#                                      46.8,
#                                      46.5,
#                                      44.4,
#                                      41.5,
#                                      41.6,
#                                      40.5,
#                                      42.0]},
#                          {'attrName': 'dateObserved',
#                           'values': ['2018-06-29T19:02:41.000',
#                                      '2018-06-29T19:07:13.000',
#                                      '2018-06-29T19:12:45.000',
#                                      '2018-06-29T19:17:17.000',
#                                      '2018-06-29T19:22:49.000',
#                                      '2018-06-29T19:27:21.000',
#                                      '2018-06-29T19:31:53.000',
#                                      '2018-06-29T19:37:25.000',
#                                      '2018-06-29T19:41:57.000',
#                                      '2018-06-29T19:47:29.000',
#                                      '2018-06-29T19:52:01.000',
#                                      '2018-06-29T19:57:33.000',
#                                      '2018-06-29T20:02:05.000',
#                                      '2018-06-29T20:07:37.000',
#                                      '2018-06-29T20:12:09.000',
#                                      '2018-06-29T20:17:41.000',
#                                      '2018-06-29T20:22:13.000',
#                                      '2018-06-29T20:27:45.000',
#                                      '2018-06-29T20:32:17.000',
#                                      '2018-06-29T20:37:49.000']},
#                          {'attrName': 'location',
#                           'values': [{'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'}]}],
#           'entityId': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54',
#           'index': ['2018-06-29T19:07:02.985',
#                     '2018-06-29T19:11:06.452',
#                     '2018-06-29T19:17:03.710',
#                     '2018-06-29T19:21:07.191',
#                     '2018-06-29T19:27:04.308',
#                     '2018-06-29T19:31:07.855',
#                     '2018-06-29T19:36:11.239',
#                     '2018-06-29T19:42:04.805',
#                     '2018-06-29T19:46:08.141',
#                     '2018-06-29T19:52:05.531',
#                     '2018-06-29T19:56:07.987',
#                     '2018-06-29T20:02:05.749',
#                     '2018-06-29T20:06:08.375',
#                     '2018-06-29T20:12:06.279',
#                     '2018-06-29T20:16:09.067',
#                     '2018-06-29T20:22:06.801',
#                     '2018-06-29T20:26:10.089',
#                     '2018-06-29T20:32:07.567',
#                     '2018-06-29T20:36:10.506',
#                     '2018-06-29T20:42:07.934']}}

# %% [markdown]
# # Georeferenced Data
#
# The final resource are the georeferenced data, which is the API of the city hall that has geographical data. Each dataset has a query builder, which you can experiment with. It is accessible by the URL and on the bottom of the page you can click “query”. All the queries must have at least the “where” parameter set, which works just like a postgresql query.
#
# Example: [https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/13](https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/13)

# %%
import json
import requests
import pprint


req_params = {
    'f': 'json',
    'where': "1=1",                        # 'where' clause is mandatory it takes a postgres-like query
    #'where': "n_o > 10",                  # example where the number of reports event was over 10
    #'where': "freguesia = 'Bonfim'",      # example for all the reports in 'Bonfim'
    #'where': "ano > 2000",                # Caveat: For example in this dataset, this will not work as 'ano' is defined as "esriFieldTypeString"
    'returnGeometry': 'true',
    'outFields': '*',                      # the fields that you want returned
    'orderByFields': 'objectid ASC', 
    #'resultOffset': '4000',
    'resultRecordCount': '10',             #for the purpose of the demonstration we are limiting to 10 results
    'outSR': '4326',
    #'token': str(TOKEN) 
}
  
url = 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/13/query'
r = requests.get(url, params = req_params)
data = r.json()

for myItem in data['features']:
  myItemAttributes = myItem['attributes']
  pprint.pprint(myItemAttributes)
# Out:
# {'c_i_final': 'C3',
#  'c_i_incial': 'C3',
#  'cod_eixo': 'S2',
#  'cod_freg': '05',
#  'cod_gis': '05211000396',
#  'cod_sgr': '2110',
#  'cod_topo': 'TAFOZ0',
#  'cod_topo_f': 'RAFOZ0',
#  'cod_topo_i': 'Y',
#  'datareg': 1138147200000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': 'BOM',
#  'n_ordem': '00396',
#  'n_zona': 0,
#  'objectid': 47626,
#  'oneway': None,
#  'st_length(shape)': 32.111482484536275,
#  'tempo': 0.03853378,
#  'tipo': 'Betao Betuminoso',
#  'toponimo': 'Travessa do Adro da Foz',
#  'usr': 0}
# {'c_i_final': 'D15',
#  'c_i_incial': 'D15',
#  'cod_eixo': 'S2',
#  'cod_freg': '03',
#  'cod_gis': '03210401391',
#  'cod_sgr': '2104',
#  'cod_topo': 'ACLEO0',
#  'cod_topo_f': 'NAREI0',
#  'cod_topo_i': 'RCASA1',
#  'datareg': 1247184000000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': None,
#  'n_ordem': '01391',
#  'n_zona': 0,
#  'objectid': 47627,
#  'oneway': 'FT',
#  'st_length(shape)': 274.76098090213446,
#  'tempo': 0.32971318,
#  'tipo': None,
#  'toponimo': 'Avenida da Cidade de León',
#  'usr': 0}
# {'c_i_final': 'D15',
#  'c_i_incial': 'D15',
#  'cod_eixo': 'S2',
#  'cod_freg': '03',
#  'cod_gis': '03210401389',
#  'cod_sgr': '2104',
#  'cod_topo': 'ACLEO0',
#  'cod_topo_f': 'NAREI0',
#  'cod_topo_i': 'RCASA1',
#  'datareg': 1247184000000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': None,
#  'n_ordem': '01389',
#  'n_zona': 0,
#  'objectid': 47628,
#  'oneway': 'TF',
#  'st_length(shape)': 50.7000816251125,
#  'tempo': 0.0608401,
#  'tipo': None,
#  'toponimo': 'Avenida da Cidade de León',
#  'usr': 0}
# {'c_i_final': 'D15',
#  'c_i_incial': 'D15',
#  'cod_eixo': 'S2',
#  'cod_freg': '03',
#  'cod_gis': '03210401388',
#  'cod_sgr': '2104',
#  'cod_topo': 'ACLEO0',
#  'cod_topo_f': 'NAREI0',
#  'cod_topo_i': 'RCASA1',
#  'datareg': 1247184000000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': None,
#  'n_ordem': '01388',
#  'n_zona': 0,
#  'objectid': 47629,
#  'oneway': 'FT',
#  'st_length(shape)': 38.83908056019778,
#  'tempo': 0.0466069,
#  'tipo': None,
#  'toponimo': 'Avenida da Cidade de León',
#  'usr': 0}
# {'c_i_final': 'D15',
#  'c_i_incial': 'D15',
#  'cod_eixo': 'S2',
#  'cod_freg': '03',
#  'cod_gis': '03210401393',
#  'cod_sgr': '2104',
#  'cod_topo': 'ACLEO0',
#  'cod_topo_f': 'NAREI0',
#  'cod_topo_i': 'RCASA1',
#  'datareg': 1247184000000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': None,
#  'n_ordem': '01393',
#  'n_zona': 0,
#  'objectid': 47630,
#  'oneway': 'TF',
#  'st_length(shape)': 91.06431704328261,
#  'tempo': 0.10927718,
#  'tipo': None,
#  'toponimo': 'Avenida da Cidade de León',
#  'usr': 0}
# {'c_i_final': 'E13',
#  'c_i_incial': 'D14',
#  'cod_eixo': 'S1',
#  'cod_freg': '03',
#  'cod_gis': '03210401404',
#  'cod_sgr': '2104',
#  'cod_topo': 'AAAND0',
#  'cod_topo_f': 'RCART0',
#  'cod_topo_i': 'RRIBE1',
#  'datareg': 1512000000000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': None,
#  'n_ordem': '01404',
#  'n_zona': 0,
#  'objectid': 47631,
#  'oneway': 'FT',
#  'st_length(shape)': 227.8919619940946,
#  'tempo': 0.27347035,
#  'tipo': None,
#  'toponimo': 'Avenida Artur de Andrade',
#  'usr': 0}
# {'c_i_final': None,
#  'c_i_incial': None,
#  'cod_eixo': 'S2',
#  'cod_freg': '03',
#  'cod_gis': '03210801371',
#  'cod_sgr': '2108',
#  'cod_topo': 'RPMBA0',
#  'cod_topo_f': None,
#  'cod_topo_i': None,
#  'datareg': 1181260800000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': None,
#  'n_ordem': '01371',
#  'n_zona': 0,
#  'objectid': 47632,
#  'oneway': None,
#  'st_length(shape)': 78.17367106437067,
#  'tempo': 0.09380841,
#  'tipo': None,
#  'toponimo': 'Rua Professor Manuel Baganha',
#  'usr': 0}
# {'c_i_final': 'D16',
#  'c_i_incial': 'B13',
#  'cod_eixo': 'S1',
#  'cod_freg': '03',
#  'cod_gis': '03210200076',
#  'cod_sgr': '2102',
#  'cod_topo': 'ICVNO0',
#  'cod_topo_f': 'U',
#  'cod_topo_i': 'RFREI1',
#  'datareg': 1181260800000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': 'BOM',
#  'n_ordem': '00076',
#  'n_zona': 0,
#  'objectid': 47633,
#  'oneway': 'FT',
#  'st_length(shape)': 456.54902306685176,
#  'tempo': 0.54785883,
#  'tipo': 'Betao Betuminoso',
#  'toponimo': 'Itinerário Complementar IC29',
#  'usr': 0}
# {'c_i_final': None,
#  'c_i_incial': None,
#  'cod_eixo': 'S1',
#  'cod_freg': '03',
#  'cod_gis': '03210601399',
#  'cod_sgr': '2106',
#  'cod_topo': 'RCART0',
#  'cod_topo_f': None,
#  'cod_topo_i': None,
#  'datareg': 1181260800000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': 'BOM',
#  'n_ordem': '01399',
#  'n_zona': 0,
#  'objectid': 47634,
#  'oneway': 'FT',
#  'st_length(shape)': 32.41582251436429,
#  'tempo': 0.03889899,
#  'tipo': 'Betao Betuminoso',
#  'toponimo': 'Rotunda de Cartes',
#  'usr': 0}
# {'c_i_final': None,
#  'c_i_incial': None,
#  'cod_eixo': 'S1',
#  'cod_freg': '10',
#  'cod_gis': '10210601195',
#  'cod_sgr': '2106',
#  'cod_topo': 'RJCVN0',
#  'cod_topo_f': None,
#  'cod_topo_i': None,
#  'datareg': 1512000000000,
#  'delflag': 0,
#  'erros': 'OK',
#  'estado': 'BOM',
#  'n_ordem': '01195',
#  'n_zona': 0,
#  'objectid': 47635,
#  'oneway': 'FT',
#  'st_length(shape)': 22.705764585317787,
#  'tempo': 0.02724692,
#  'tipo': 'Betao Betuminoso',
#  'toponimo': 'Rotunda Joaquim Cardoso Vila Nova',
#  'usr': 0}
