# %% [markdown]
# # PORTO CITY DATA
#
#
# All the city data from Porto is indexed at Porto's CKAN platform: https://opendata.urbanplatform.portodigital.pt/.
#
# All the data is downloadable from the CKAN platform directly in various formats (CSV, images, etc...). The exception is the IoT data, which is available from a separate API endpoint, but which is indexed by CKAN.

# %% [markdown]
# # The CKAN Platorm
#
# CKAN is a tool for making open data websites. (Think of a content management system like WordPress - but for data, instead of pages and blog posts). It helps you manage and publish collections of data.
#
# Once your data is published, users can use its faceted search features to browse and find the data they need, and preview it using maps, graphs and tables - whether they are developers, journalists, researchers, NGOs, citizens, or even your own staff.
#
# **Datasets and resources**
#
# For CKAN purposes, data is published in units called “datasets”. A dataset is a parcel of data - for example, it could be the crime statistics for a region, the spending figures for a government department, or temperature readings from various weather stations. When users search for data, the search results they see will be individual datasets.
#
# A dataset contains two things:
#
# * ***Metadata***: Information about the data.
# For example, the title and publisher, date, what formats it is available in, what license it is released under, etc.
# * ***Resources***: The data itself. CKAN does not mind what format the data is in. A resource can be a CSV or Excel spreadsheet, XML file, PDF document, image file, linked data in RDF format, etc. CKAN can store the resource internally, or store it simply as a link, the resource itself being elsewhere on the web.
#
# Note: On early CKAN versions, datasets were called “packages” and this name has stuck in some places, specially internally and on API calls. Package has exactly the same meaning as “dataset”.
#
# **API documentation**
# * CKAN: https://docs.ckan.org/en/2.8/api/
#
# **API endpoints**
# * CKAN: https://opendata.urbanplatform.portodigital.pt/api/3/

# %% [markdown]
# ## Available Data Sets & Resources
#
# Bellow you can find the API call which lists all available datasets.

# %%
## Porto's CKAN Platform examples
## Show all the datasets available (aka packages)

import pprint
import requests
url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_list";
r = requests.get(url)
pprint.pprint(r.json())
# Out:
# {'help': 'https://opendata.urbanplatform.portodigital.pt/api/3/action/help_show?name=package_list',
#  'result': ['agua-de-nascente',
#             'alojamento-local',
#             'alojamentos-hoteleiros-2011',
#             'apdg-areas-de-reabilitacao-urbana-arus',
#             'apdg-estabelecimentos-com-medidas-de-autoproteccao-map',
#             'apdg-porto-de-tradicao-no-de-estabelecimentos-reconhecidos-por-ano',
#             'apdg-zonas-de-estacionamento-pago',
#             'areas-edificadas',
#             'areas-verdes',
#             'atlas-desportivo',
#             'bairros-de-casas-economicas-do-estado-novo',
#             'balizas-de-sinalizacao',
#             'bicicletarios',
#             'carta-de-patrimonio',
#             'cemiterios-municipais-ou-privados-2007',
#             'centros-de-saude-e-extensoes-2001',
#             'dissuasores-de-controlo-de-acessos',
#             'ecocentros-2006',
#             'edificios-de-interesse-publico',
#             'edificios-de-interesse-publico-2012',
#             'eixos-de-via-infraestruturas-portugal',
#             'equipamentos-de-saude',
#             'estabelecimentos-de-ensino-por-ano-letivo',
#             'feiras-e-mercados-2011',
#             'fontes-de-contaminacao--cemiterios-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao--cemiterios-carta-hidrogeologica',
#             'fontes-de-contaminacao--depositos-de-lixo-misto-aterrados-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao--depositos-de-lixo-misto-aterrados-carta-hidrogeologica',
#             'fontes-de-contaminacao-entulheiras-aterradas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao--entulheiras-aterradas-carta-hidrogeologica',
#             'fontes-de-contaminacao--entulheiras-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao--entulheiras-carta-hidrogeologica',
#             'fontes-de-contaminacao--lixeiras-aterradas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao--lixeiras-aterradas-carta-hidrogeologica',
#             'furos-de-captacao-de-agua',
#             'georisk--carta-de-ocorrencias',
#             'informacao-publica-dos-servicos-de-transporte-colectivo-do-porto',
#             'limites-de-freguesias-1956',
#             'metro-do-porto',
#             'nascentes',
#             'parcometros-zonas-de-estacionamento-pago',
#             'parques-de-estacionamento-municipais',
#             'parques-de-motociclos',
#             'piscinas-centroides',
#             'pocos',
#             'porto-meteorologia',
#             'porto-niveis-ruido',
#             'porto-pontos-de-acesso-wifi-apd',
#             'porto-pontos-de-interesse',
#             'porto-qualidade-do-ar',
#             'porto-transito',
#             'porto-veiculos-do-municipio',
#             'postos-de-abastecimento-de-combustiveis-centroides',
#             'postos-de-informacao-turistica-centroides',
#             'praca-de-taxis',
#             'processos-de-fiscalizacao-ambito-do-dep-municipal-de-fiscalizacao',
#             'recintos-musicais-centroides',
#             'recintos-polidesportivos-centroides',
#             'reparticoes-de-financas-e-tesourarias-servicos-centroides',
#             'restaurantes-centroides',
#             'ruido--zona-mista',
#             'ruido--zona-mista-2012',
#             'ruido--zona-sensivel',
#             'ruido--zona-sensivel-2012',
#             'sinalizacao-led-em-travessias-de-peoes',
#             'stcp-autocarros-paragens-centroides',
#             'superficies-comerciais--distribuicao-centroides',
#             'teatros-centroides',
#             'templos-religiosos-centroides',
#             'transito_-impedimentos-e-obras-online',
#             'transportes-publicos-stcp',
#             'tribunais-centroides',
#             'zona-de-recolha-de-residuos',
#             'zonas-de-comercio-tradicional-centroides',
#             'zonas-instaveis-mais-criticas',
#             'zonas-instaveis-menos-criticas',
#             'zonas-potencialmente-instaveis'],
#  'success': True}

# %% [markdown]
# ## Resource
#
# You can find all kind of information regarding a dataset. Each dataset can have multiple resources, which can be accessed through the respective URL.

# %%
## Porto's CKAN Platform examples
## In this example we look at the parking zones in the city

import pprint
import requests
url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_show?id=apdg-zonas-de-estacionamento-pago";
r = requests.get(url)
j = r.json()
print("Resources: ")
for resource in j['result']['resources']:
  print("{}({}):".format(resource['name'], resource['format']))
  print(resource['url'] + "\n")
print("Full resource information: ")
pprint.pprint(j)
# Out:
# Resources:
# apdg-zonas-de-estacionamento-pago.csv(CSV):
# https://opendata.urbanplatform.portodigital.pt/dataset/d5d1106b-5db6-4434-b1b2-9083d9fb1f49/resource/7cbe9afa-04c1-45a6-ae81-08b5fffc53a7/download/apdg-zonas-de-estacionamento-pago.csv
#
# Full resource information:
# {'help': 'https://opendata.urbanplatform.portodigital.pt/api/3/action/help_show?name=package_show',
#  'result': {'author': None,
#             'author_email': None,
#             'creator_user_id': '935842fc-3252-4867-ada8-6f7cced693a1',
#             'extras': [],
#             'groups': [],
#             'id': 'd5d1106b-5db6-4434-b1b2-9083d9fb1f49',
#             'isopen': True,
#             'license_id': 'cc-by',
#             'license_title': 'Creative Commons Attribution',
#             'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#             'maintainer': None,
#             'maintainer_email': None,
#             'metadata_created': '2018-07-04T08:09:49.684131',
#             'metadata_modified': '2018-07-04T17:44:56.732446',
#             'name': 'apdg-zonas-de-estacionamento-pago',
#             'notes': 'Zonas de estacionamento pago',
#             'num_resources': 1,
#             'num_tags': 0,
#             'organization': {'approval_status': 'approved',
#                              'created': '2018-06-29T16:43:31.797549',
#                              'description': 'Câmara Municipal do Porto',
#                              'id': '27054936-759b-4127-a0c5-ef6bbe6140f3',
#                              'image_url': '',
#                              'is_organization': True,
#                              'name': 'cmporto',
#                              'revision_id': 'c602eb39-6f3d-4121-ba4e-1a7bdc925a03',
#                              'state': 'active',
#                              'title': 'C. M. Porto',
#                              'type': 'organization'},
#             'owner_org': '27054936-759b-4127-a0c5-ef6bbe6140f3',
#             'private': False,
#             'relationships_as_object': [],
#             'relationships_as_subject': [],
#             'resources': [{'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-07-04T09:45:53.794356',
#                            'datastore_active': True,
#                            'description': '',
#                            'encoding': 'utf-8',
#                            'format': 'CSV',
#                            'hash': '',
#                            'id': '7cbe9afa-04c1-45a6-ae81-08b5fffc53a7',
#                            'last_modified': '2018-07-04T17:44:56.722007',
#                            'mimetype': 'text/csv',
#                            'mimetype_inner': None,
#                            'name': 'apdg-zonas-de-estacionamento-pago.csv',
#                            'package_id': 'd5d1106b-5db6-4434-b1b2-9083d9fb1f49',
#                            'position': 0,
#                            'resource_type': None,
#                            'revision_id': 'a1924b0d-66db-4cd9-b2e7-bd0306e91ab0',
#                            'size': 130660,
#                            'state': 'active',
#                            'url': 'https://opendata.urbanplatform.portodigital.pt/dataset/d5d1106b-5db6-4434-b1b2-9083d9fb1f49/resource/7cbe9afa-04c1-45a6-ae81-08b5fffc53a7/download/apdg-zonas-de-estacionamento-pago.csv',
#                            'url_type': 'upload'}],
#             'revision_id': '284bf75e-7ccf-4a54-9a8f-b0f573bfe993',
#             'state': 'active',
#             'tags': [],
#             'title': 'Zonas de estacionamento pago',
#             'type': 'dataset',
#             'url': None,
#             'version': None},
#  'success': True}

# %%
## Example of an API enpoint indexed by CKAN

import requests
url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_show?id=porto-meteorologia"
r = requests.get(url)
j = r.json()
for resource in j['result']['resources']:
  print("{}({}):".format(resource['name'], resource['format']))
  print(resource['url'] + "\n")
# Out:
# PORTO Meteorologia - Valores observados(fiware-ngsi):
# https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherObserved
#
# PORTO Meteorologia - Previsão(fiware-ngsi):
# https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherForecast

# %% [markdown]
# # IoT Data
#
# A special resource is the information from the IoT platform, which is accessible through the NGSI API. The historical data for each is available at a seperate endpoint.
#
# **Types**: Are types of devices or data \\
# **Entities**: Each entity is a device of a certain type
#
# **API documentation**
# * NGIS: https://fiware-orion.readthedocs.io/en/2.0.0/user/walkthrough_apiv2/#query-entity
# * Data format: https://gitlab.com/synchronicity-iot/synchronicity-data-models/
# * Historical data: http://history-data.urbanplatform.portodigital.pt/v2/ui/
#
# **API endpoints**
# * Live Data:  https://broker.fiware.urbanplatform.portodigital.pt/v2/
# * Historical Data: http://history-data.urbanplatform.portodigital.pt/v2/

# %%
## List of all IoT resources with the respective data type

import requests
import json

url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/types"
r = requests.get(url)
j = r.json()

for item in j:
  print("{} ({}):".format(item["type"], item["count"]))
  attrs = item['attrs']
  print("{:<30} {:<15}".format('Name','Types'))
  for k, v in attrs.items():
    print("{:<30} {:<15}".format(k, ", ".join(v['types'])))
  print("")
# Out:
# AirQualityObserved (5):
# Name                           Types
# CO                             Number
# NO2                            Number
# O3                             Number
# Ox                             Number
# PM1                            Number
# PM10                           Number
# PM25                           Number
# dateObserved                   DateTime
# location                       geo:json
#
# ArrivalEstimation (8):
# Name                           Types
# dateModified                   DateTime
# description                    Text
# headSign                       StructuredValue
# remainingTime                  StructuredValue
#
# Device (191):
# Name                           Types
# category                       StructuredValue
# configuration                  StructuredValue
# controlledAsset                StructuredValue
# controlledProperty             StructuredValue
# dateExpires                    DateTime
# dateModified                   DateTime
# description                    None, Text
# l_serialNumber                 None, Text
# location                       None, geo:json
# name                           Text
# owner                          StructuredValue
# value                          Text
#
# Event (6199):
# Name                           Types
# address                        StructuredValue
# dateModified                   Text
# description                    Text
# description_es                 Text
# description_pt                 Text
# discounts                      Text
# discounts_es                   Text
# discounts_pt                   Text
# endDate                        StructuredValue, Text
# informationUrl                 Text
# informationUrl_es              Text
# informationUrl_pt              Text
# location                       Text, geo:json
# multimedia                     StructuredValue, Text
# name                           Text
# name_es                        Text
# name_pt                        Text
# observations                   Text
# observations_es                Text
# observations_pt                Text
# promoter                       Text
# promoter_es                    Text
# promoter_pt                    Text
# reservationUrl                 Text
# reservationUrl_es              Text
# reservationUrl_pt              Text
# schedule                       Text
# schedule_es                    Text
# schedule_pt                    Text
# specifications                 Text
# specifications_es              Text
# specifications_pt              Text
# startDate                      Text
# target                         Text
# target_es                      Text
# target_pt                      Text
# theme                          StructuredValue, Text
# theme_es                       StructuredValue, Text
# theme_pt                       StructuredValue, Text
#
# GtfsTransitFeedFile (1):
# Name                           Types
# description                    Text
# endDate                        Text
# feedFileURL                    Text
# publisher                      StructuredValue
# startDate                      Text
# version                        StructuredValue
#
# NoiseLevelObserved (15):
# Name                           Types
# LAeq                           Number
# dateObserved                   DateTime
# dateObservedFrom               DateTime
# dateObservedTo                 DateTime
# location                       geo:json
# measurand                      StructuredValue
#
# OffStreetParking (1):
# Name                           Types
# allowedVehicleType             StructuredValue
# availableSpotNumber            Number
# category                       StructuredValue
# chargeType                     StructuredValue
# location                       StructuredValue
# name                           Text
# occupancyDetectionType         StructuredValue
# requiredPermit                 StructuredValue
# totalSpotNumber                Number
#
# PointOfInterest (3060):
# Name                           Types
# accessibility                  None, StructuredValue, Text
# accessibility_es               None, StructuredValue, Text
# accessibility_pt               None, StructuredValue, Text
# address                        StructuredValue
# category                       StructuredValue
# closedOnHoliday                Text
# contactPoint                   StructuredValue
# costDescription                Text
# costDescription_es             Text
# costDescription_pt             Text
# dateModified                   DateTime, Text
# description                    None, Text
# description_es                 None, Text
# description_pt                 None, Text
# internetAccess                 None, Text
# internetWireless               None, Text
# location                       StructuredValue, Text, geo:json
# multimedia                     StructuredValue
# name                           Text
# name_es                        Text
# name_pt                        Text
# openingHoursSpecification      StructuredValue
# smokingArea                    None, Text
# socialNetwork                  StructuredValue, Text
# tag                            None, StructuredValue, Text
# tag_es                         None, StructuredValue, Text
# tag_pt                         None, StructuredValue, Text
# target                         StructuredValue, Text
# target_es                      StructuredValue, Text
# target_pt                      StructuredValue, Text
# touristic                      Text
# wifi                           None, Text
#
# TrafficFlowObserved (115):
# Name                           Types
# dateModified                   DateTime, Text
# dateObserved                   Text
# dateObservedFrom               DateTime, Text
# dateObservedTo                 DateTime, Text
# intensity                      Number
# laneId                         Number
# location                       geo:json
#
# Vehicle (246):
# Name                           Types
# category                       StructuredValue
# dateModified                   DateTime, Text
# latitude                       Number
# location                       geo:json
# longitude                      Number
# speed                          Number
# vehicleType                    Text
#
# WeatherForecast (131):
# Name                           Types
# address                        PostalAddress
# dataProvider                   Text
# dateIssued                     DateTime
# dateRetrieved                  DateTime
# dayMaximum                     StructuredValue
# dayMinimum                     StructuredValue
# feelsLikeTemperature           None, Number
# location                       geo:json
# precipitationProbability       None, Number
# relativeHumidity               None, Number
# source                         URL
# temperature                    None, Number
# validFrom                      DateTime
# validTo                        DateTime
# validity                       Text
# weatherType                    Text
# windDirection                  Number
# windSpeed                      None, Number
#
# WeatherObserved (17):
# Name                           Types
# PM1                            Number
# PM10                           Number
# PM25                           Number
# barometricPressure             Float, Number
# dataProvider                   String
# dateObserved                   DateTime
# dewPoint                       Number
# location                       geo:json
# name                           String
# precipitation                  Float
# relativeHumidity               Number
# solarRadiation                 Number
# source                         url
# temperature                    Number
# windDirection                  Float, Number
# windSpeed                      Float, Number
#
# gtfsAgency (1):
# Name                           Types
# language                       Text
# name                           Text
# page                           Text
# timezone                       Text
#
# gtfsCalendarDateRule (6):
# Name                           Types
# appliesOn                      Text
# exceptionType                  Text
# hasService                     Text
#
# gtfsCalendarRule (15):
# Name                           Types
# endDate                        Text
# friday                         Boolean
# hasService                     Text
# monday                         Boolean
# saturday                       Boolean
# startDate                      Text
# sunday                         Boolean
# thursday                       Boolean
# tuesday                        Boolean
# wednesday                      Boolean
#
# gtfsRoute (73):
# Name                           Types
# description                    Text
# name                           Text
# page                           Text
# routeColor                     Text
# routeID                        Text
# routeTextColor                 Text
# routeType                      Text
# shortName                      Text
#
# gtfsService (15):
# Name                           Types
# code                           Text
# operatedBy                     Text
#
# gtfsStop (2468):
# Name                           Types
# code                           Text
# location                       geo:json
# name                           Text
# page                           Text
# zoneCode                       Text

# %% [markdown]
# ## Accessing Live Value
# All the live value are available through the FiWare broker, as described in the documentation on top.

# %%
## You can access live values through the fiware broker

import requests
import pprint
url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/types"
r = requests.get(url)
j = r.json()
pprint.pprint(j)
# Out:
# [{'attrs': {'CO': {'types': ['Number']},
#             'NO2': {'types': ['Number']},
#             'O3': {'types': ['Number']},
#             'Ox': {'types': ['Number']},
#             'PM1': {'types': ['Number']},
#             'PM10': {'types': ['Number']},
#             'PM25': {'types': ['Number']},
#             'dateObserved': {'types': ['DateTime']},
#             'location': {'types': ['geo:json']}},
#   'count': 5,
#   'type': 'AirQualityObserved'},
#  {'attrs': {'dateModified': {'types': ['DateTime']},
#             'description': {'types': ['Text']},
#             'headSign': {'types': ['StructuredValue']},
#             'remainingTime': {'types': ['StructuredValue']}},
#   'count': 8,
#   'type': 'ArrivalEstimation'},
#  {'attrs': {'category': {'types': ['StructuredValue']},
#             'configuration': {'types': ['StructuredValue']},
#             'controlledAsset': {'types': ['StructuredValue']},
#             'controlledProperty': {'types': ['StructuredValue']},
#             'dateExpires': {'types': ['DateTime']},
#             'dateModified': {'types': ['DateTime']},
#             'description': {'types': ['None', 'Text']},
#             'l_serialNumber': {'types': ['None', 'Text']},
#             'location': {'types': ['None', 'geo:json']},
#             'name': {'types': ['Text']},
#             'owner': {'types': ['StructuredValue']},
#             'value': {'types': ['Text']}},
#   'count': 191,
#   'type': 'Device'},
#  {'attrs': {'address': {'types': ['StructuredValue']},
#             'dateModified': {'types': ['Text']},
#             'description': {'types': ['Text']},
#             'description_es': {'types': ['Text']},
#             'description_pt': {'types': ['Text']},
#             'discounts': {'types': ['Text']},
#             'discounts_es': {'types': ['Text']},
#             'discounts_pt': {'types': ['Text']},
#             'endDate': {'types': ['StructuredValue', 'Text']},
#             'informationUrl': {'types': ['Text']},
#             'informationUrl_es': {'types': ['Text']},
#             'informationUrl_pt': {'types': ['Text']},
#             'location': {'types': ['Text', 'geo:json']},
#             'multimedia': {'types': ['StructuredValue', 'Text']},
#             'name': {'types': ['Text']},
#             'name_es': {'types': ['Text']},
#             'name_pt': {'types': ['Text']},
#             'observations': {'types': ['Text']},
#             'observations_es': {'types': ['Text']},
#             'observations_pt': {'types': ['Text']},
#             'promoter': {'types': ['Text']},
#             'promoter_es': {'types': ['Text']},
#             'promoter_pt': {'types': ['Text']},
#             'reservationUrl': {'types': ['Text']},
#             'reservationUrl_es': {'types': ['Text']},
#             'reservationUrl_pt': {'types': ['Text']},
#             'schedule': {'types': ['Text']},
#             'schedule_es': {'types': ['Text']},
#             'schedule_pt': {'types': ['Text']},
#             'specifications': {'types': ['Text']},
#             'specifications_es': {'types': ['Text']},
#             'specifications_pt': {'types': ['Text']},
#             'startDate': {'types': ['Text']},
#             'target': {'types': ['Text']},
#             'target_es': {'types': ['Text']},
#             'target_pt': {'types': ['Text']},
#             'theme': {'types': ['StructuredValue', 'Text']},
#             'theme_es': {'types': ['StructuredValue', 'Text']},
#             'theme_pt': {'types': ['StructuredValue', 'Text']}},
#   'count': 6199,
#   'type': 'Event'},
#  {'attrs': {'description': {'types': ['Text']},
#             'endDate': {'types': ['Text']},
#             'feedFileURL': {'types': ['Text']},
#             'publisher': {'types': ['StructuredValue']},
#             'startDate': {'types': ['Text']},
#             'version': {'types': ['StructuredValue']}},
#   'count': 1,
#   'type': 'GtfsTransitFeedFile'},
#  {'attrs': {'LAeq': {'types': ['Number']},
#             'dateObserved': {'types': ['DateTime']},
#             'dateObservedFrom': {'types': ['DateTime']},
#             'dateObservedTo': {'types': ['DateTime']},
#             'location': {'types': ['geo:json']},
#             'measurand': {'types': ['StructuredValue']}},
#   'count': 15,
#   'type': 'NoiseLevelObserved'},
#  {'attrs': {'allowedVehicleType': {'types': ['StructuredValue']},
#             'availableSpotNumber': {'types': ['Number']},
#             'category': {'types': ['StructuredValue']},
#             'chargeType': {'types': ['StructuredValue']},
#             'location': {'types': ['StructuredValue']},
#             'name': {'types': ['Text']},
#             'occupancyDetectionType': {'types': ['StructuredValue']},
#             'requiredPermit': {'types': ['StructuredValue']},
#             'totalSpotNumber': {'types': ['Number']}},
#   'count': 1,
#   'type': 'OffStreetParking'},
#  {'attrs': {'accessibility': {'types': ['None', 'StructuredValue', 'Text']},
#             'accessibility_es': {'types': ['None', 'StructuredValue', 'Text']},
#             'accessibility_pt': {'types': ['None', 'StructuredValue', 'Text']},
#             'address': {'types': ['StructuredValue']},
#             'category': {'types': ['StructuredValue']},
#             'closedOnHoliday': {'types': ['Text']},
#             'contactPoint': {'types': ['StructuredValue']},
#             'costDescription': {'types': ['Text']},
#             'costDescription_es': {'types': ['Text']},
#             'costDescription_pt': {'types': ['Text']},
#             'dateModified': {'types': ['DateTime', 'Text']},
#             'description': {'types': ['None', 'Text']},
#             'description_es': {'types': ['None', 'Text']},
#             'description_pt': {'types': ['None', 'Text']},
#             'internetAccess': {'types': ['None', 'Text']},
#             'internetWireless': {'types': ['None', 'Text']},
#             'location': {'types': ['StructuredValue', 'Text', 'geo:json']},
#             'multimedia': {'types': ['StructuredValue']},
#             'name': {'types': ['Text']},
#             'name_es': {'types': ['Text']},
#             'name_pt': {'types': ['Text']},
#             'openingHoursSpecification': {'types': ['StructuredValue']},
#             'smokingArea': {'types': ['None', 'Text']},
#             'socialNetwork': {'types': ['StructuredValue', 'Text']},
#             'tag': {'types': ['None', 'StructuredValue', 'Text']},
#             'tag_es': {'types': ['None', 'StructuredValue', 'Text']},
#             'tag_pt': {'types': ['None', 'StructuredValue', 'Text']},
#             'target': {'types': ['StructuredValue', 'Text']},
#             'target_es': {'types': ['StructuredValue', 'Text']},
#             'target_pt': {'types': ['StructuredValue', 'Text']},
#             'touristic': {'types': ['Text']},
#             'wifi': {'types': ['None', 'Text']}},
#   'count': 3060,
#   'type': 'PointOfInterest'},
#  {'attrs': {'dateModified': {'types': ['DateTime', 'Text']},
#             'dateObserved': {'types': ['Text']},
#             'dateObservedFrom': {'types': ['DateTime', 'Text']},
#             'dateObservedTo': {'types': ['DateTime', 'Text']},
#             'intensity': {'types': ['Number']},
#             'laneId': {'types': ['Number']},
#             'location': {'types': ['geo:json']}},
#   'count': 115,
#   'type': 'TrafficFlowObserved'},
#  {'attrs': {'category': {'types': ['StructuredValue']},
#             'dateModified': {'types': ['DateTime', 'Text']},
#             'latitude': {'types': ['Number']},
#             'location': {'types': ['geo:json']},
#             'longitude': {'types': ['Number']},
#             'speed': {'types': ['Number']},
#             'vehicleType': {'types': ['Text']}},
#   'count': 246,
#   'type': 'Vehicle'},
#  {'attrs': {'address': {'types': ['PostalAddress']},
#             'dataProvider': {'types': ['Text']},
#             'dateIssued': {'types': ['DateTime']},
#             'dateRetrieved': {'types': ['DateTime']},
#             'dayMaximum': {'types': ['StructuredValue']},
#             'dayMinimum': {'types': ['StructuredValue']},
#             'feelsLikeTemperature': {'types': ['None', 'Number']},
#             'location': {'types': ['geo:json']},
#             'precipitationProbability': {'types': ['None', 'Number']},
#             'relativeHumidity': {'types': ['None', 'Number']},
#             'source': {'types': ['URL']},
#             'temperature': {'types': ['None', 'Number']},
#             'validFrom': {'types': ['DateTime']},
#             'validTo': {'types': ['DateTime']},
#             'validity': {'types': ['Text']},
#             'weatherType': {'types': ['Text']},
#             'windDirection': {'types': ['Number']},
#             'windSpeed': {'types': ['None', 'Number']}},
#   'count': 131,
#   'type': 'WeatherForecast'},
#  {'attrs': {'PM1': {'types': ['Number']},
#             'PM10': {'types': ['Number']},
#             'PM25': {'types': ['Number']},
#             'barometricPressure': {'types': ['Float', 'Number']},
#             'dataProvider': {'types': ['String']},
#             'dateObserved': {'types': ['DateTime']},
#             'dewPoint': {'types': ['Number']},
#             'location': {'types': ['geo:json']},
#             'name': {'types': ['String']},
#             'precipitation': {'types': ['Float']},
#             'relativeHumidity': {'types': ['Number']},
#             'solarRadiation': {'types': ['Number']},
#             'source': {'types': ['url']},
#             'temperature': {'types': ['Number']},
#             'windDirection': {'types': ['Float', 'Number']},
#             'windSpeed': {'types': ['Float', 'Number']}},
#   'count': 17,
#   'type': 'WeatherObserved'},
#  {'attrs': {'language': {'types': ['Text']},
#             'name': {'types': ['Text']},
#             'page': {'types': ['Text']},
#             'timezone': {'types': ['Text']}},
#   'count': 1,
#   'type': 'gtfsAgency'},
#  {'attrs': {'appliesOn': {'types': ['Text']},
#             'exceptionType': {'types': ['Text']},
#             'hasService': {'types': ['Text']}},
#   'count': 6,
#   'type': 'gtfsCalendarDateRule'},
#  {'attrs': {'endDate': {'types': ['Text']},
#             'friday': {'types': ['Boolean']},
#             'hasService': {'types': ['Text']},
#             'monday': {'types': ['Boolean']},
#             'saturday': {'types': ['Boolean']},
#             'startDate': {'types': ['Text']},
#             'sunday': {'types': ['Boolean']},
#             'thursday': {'types': ['Boolean']},
#             'tuesday': {'types': ['Boolean']},
#             'wednesday': {'types': ['Boolean']}},
#   'count': 15,
#   'type': 'gtfsCalendarRule'},
#  {'attrs': {'description': {'types': ['Text']},
#             'name': {'types': ['Text']},
#             'page': {'types': ['Text']},
#             'routeColor': {'types': ['Text']},
#             'routeID': {'types': ['Text']},
#             'routeTextColor': {'types': ['Text']},
#             'routeType': {'types': ['Text']},
#             'shortName': {'types': ['Text']}},
#   'count': 73,
#   'type': 'gtfsRoute'},
#  {'attrs': {'code': {'types': ['Text']}, 'operatedBy': {'types': ['Text']}},
#   'count': 15,
#   'type': 'gtfsService'},
#  {'attrs': {'code': {'types': ['Text']},
#             'location': {'types': ['geo:json']},
#             'name': {'types': ['Text']},
#             'page': {'types': ['Text']},
#             'zoneCode': {'types': ['Text']}},
#   'count': 2468,
#   'type': 'gtfsStop'}]

# %% [markdown]
# ## Accessing historical values
# The historical values are accessible through the documentation described above. Because the query is quite heavy, you can only access one entity at once.

# %%
## Example of IoT Resource - Air Quality

import requests
import pprint
url = "http://history-data.urbanplatform.portodigital.pt/v2/entities/urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54?limit=20"
r = requests.get(url)
j = r.json()
pprint.pprint(j)
# Out:
# {'data': {'attributes': [{'attrName': 'CO',
#                           'values': [461.7,
#                                      461.7,
#                                      353.2,
#                                      353.2,
#                                      353.2,
#                                      446.0,
#                                      446.0,
#                                      446.0,
#                                      355.0,
#                                      355.0,
#                                      355.0,
#                                      419.3,
#                                      419.3,
#                                      419.3,
#                                      293.4,
#                                      293.4,
#                                      293.4,
#                                      359.1,
#                                      359.1,
#                                      359.1]},
#                          {'attrName': 'NO2',
#                           'values': [110.2,
#                                      110.2,
#                                      97.3,
#                                      97.3,
#                                      97.3,
#                                      83.5,
#                                      83.5,
#                                      83.5,
#                                      85.7,
#                                      85.7,
#                                      85.7,
#                                      87.6,
#                                      87.6,
#                                      87.6,
#                                      64.5,
#                                      64.5,
#                                      64.5,
#                                      69.7,
#                                      69.7,
#                                      69.7]},
#                          {'attrName': 'O3',
#                           'values': [6.8,
#                                      6.8,
#                                      12.3,
#                                      12.3,
#                                      12.3,
#                                      20.1,
#                                      20.1,
#                                      20.1,
#                                      20.0,
#                                      20.0,
#                                      20.0,
#                                      21.1,
#                                      21.1,
#                                      21.1,
#                                      31.7,
#                                      31.7,
#                                      31.7,
#                                      29.1,
#                                      29.1,
#                                      29.1]},
#                          {'attrName': 'Ox',
#                           'values': [120.8,
#                                      120.8,
#                                      112.8,
#                                      112.8,
#                                      112.8,
#                                      107.2,
#                                      107.2,
#                                      107.2,
#                                      109.4,
#                                      109.4,
#                                      109.4,
#                                      112.5,
#                                      112.5,
#                                      112.5,
#                                      99.0,
#                                      99.0,
#                                      99.0,
#                                      101.8,
#                                      101.8,
#                                      101.8]},
#                          {'attrName': 'PM1',
#                           'values': [20.0,
#                                      19.8,
#                                      22.2,
#                                      22.8,
#                                      21.6,
#                                      19.2,
#                                      18.8,
#                                      18.4,
#                                      16.8,
#                                      18.6,
#                                      17.8,
#                                      15.6,
#                                      18.8,
#                                      19.0,
#                                      18.8,
#                                      17.8,
#                                      16.8,
#                                      16.6,
#                                      16.2,
#                                      17.0]},
#                          {'attrName': 'PM10',
#                           'values': [67.3,
#                                      70.4,
#                                      69.5,
#                                      73.7,
#                                      83.6,
#                                      60.5,
#                                      66.0,
#                                      66.0,
#                                      59.4,
#                                      58.5,
#                                      64.9,
#                                      52.8,
#                                      74.8,
#                                      74.4,
#                                      61.0,
#                                      61.6,
#                                      51.1,
#                                      63.4,
#                                      60.0,
#                                      50.6]},
#                          {'attrName': 'PM25',
#                           'values': [50.0,
#                                      49.5,
#                                      54.4,
#                                      56.0,
#                                      53.6,
#                                      48.5,
#                                      47.0,
#                                      45.6,
#                                      42.4,
#                                      45.6,
#                                      45.0,
#                                      39.6,
#                                      46.0,
#                                      46.8,
#                                      46.5,
#                                      44.4,
#                                      41.5,
#                                      41.6,
#                                      40.5,
#                                      42.0]},
#                          {'attrName': 'dateObserved',
#                           'values': ['2018-06-29T19:02:41.000',
#                                      '2018-06-29T19:07:13.000',
#                                      '2018-06-29T19:12:45.000',
#                                      '2018-06-29T19:17:17.000',
#                                      '2018-06-29T19:22:49.000',
#                                      '2018-06-29T19:27:21.000',
#                                      '2018-06-29T19:31:53.000',
#                                      '2018-06-29T19:37:25.000',
#                                      '2018-06-29T19:41:57.000',
#                                      '2018-06-29T19:47:29.000',
#                                      '2018-06-29T19:52:01.000',
#                                      '2018-06-29T19:57:33.000',
#                                      '2018-06-29T20:02:05.000',
#                                      '2018-06-29T20:07:37.000',
#                                      '2018-06-29T20:12:09.000',
#                                      '2018-06-29T20:17:41.000',
#                                      '2018-06-29T20:22:13.000',
#                                      '2018-06-29T20:27:45.000',
#                                      '2018-06-29T20:32:17.000',
#                                      '2018-06-29T20:37:49.000']},
#                          {'attrName': 'location',
#                           'values': [{'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'}]}],
#           'entityId': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54',
#           'index': ['2018-06-29T19:07:02.985',
#                     '2018-06-29T19:11:06.452',
#                     '2018-06-29T19:17:03.710',
#                     '2018-06-29T19:21:07.191',
#                     '2018-06-29T19:27:04.308',
#                     '2018-06-29T19:31:07.855',
#                     '2018-06-29T19:36:11.239',
#                     '2018-06-29T19:42:04.805',
#                     '2018-06-29T19:46:08.141',
#                     '2018-06-29T19:52:05.531',
#                     '2018-06-29T19:56:07.987',
#                     '2018-06-29T20:02:05.749',
#                     '2018-06-29T20:06:08.375',
#                     '2018-06-29T20:12:06.279',
#                     '2018-06-29T20:16:09.067',
#                     '2018-06-29T20:22:06.801',
#                     '2018-06-29T20:26:10.089',
#                     '2018-06-29T20:32:07.567',
#                     '2018-06-29T20:36:10.506',
#                     '2018-06-29T20:42:07.934']}}

# %% [markdown]
# # MIP
#
# The final resource is the MIP, which is the arcGIS API of the city hall. This is where all the geographical information is available. Each dataset has a query builder, which you can experiment with. It is accessible by the URL and on the bottom of the page you can click “query”. All the queries must have at least the “where” parameter set, which works just like a postgresql query.
#
# Example: [http://mipweb.cm-porto.pt/arcgis/rest/services/APD/OpenData_APD/MapServer/13](http://mipweb.cm-porto.pt/arcgis/rest/services/APD/OpenData_APD/MapServer/13)

# %%
import json
import requests
import pprint


req_params = {
    'f': 'json',
    'where': "1=1",                        # 'where' clause is mandatory it takes a postgres-like query
    #'where': "n_o > 10",                  # example where the number of reports event was over 10
    #'where': "freguesia = 'Bonfim'",      # example for all the reports in 'Bonfim'
    #'where': "ano > 2000",                # Caveat: For example in this dataset, this will not work as 'ano' is defined as "esriFieldTypeString"
    'returnGeometry': 'true',
    'outFields': '*',                      # the fields that you want returned
    'orderByFields': 'objectid ASC', 
    #'resultOffset': '4000',
    #'resultRecordCount': '1000',
    'outSR': '4326',
    #'token': str(TOKEN) 
}
  
url = 'http://mipweb.cm-porto.pt/arcgis/rest/services/APD/OpenData_APD/MapServer/13/query'
r = requests.get(url, params = req_params)
data = r.json()

for myItem in data['features']:
  myItemAttributes = myItem['attributes']
  pprint.pprint(myItemAttributes)
# Out:
# {'ano': '1755',
#  'cgn': 1312073,
#  'cod_freg': '07',
#  'cod_gis': '07750100001',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Sismo provocou a torção e a mudança de direcção da cruz '
#                      'que servia de remate à fachada da igreja matriz de '
#                      'Massarelos.',
#  'dia': 1,
#  'freguesia': 'Massarelos',
#  'mês': 'Novembro',
#  'n_o': 3,
#  'n_ordem': '00001',
#  'objectid': 1,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1969',
#  'cgn': 1312081,
#  'cod_freg': '08',
#  'cod_gis': '08750100001',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ameaça de ruína da chaminé no 3º andar do nº 73 da rua '
#                      'Tomás Gonzaga, visto os materiais que a revestem se '
#                      'encontrarem bastante degradados e possuir uma fenda na '
#                      'sua base.',
#  'dia': 1,
#  'freguesia': 'Miragaia',
#  'mês': 'Março',
#  'n_o': 34,
#  'n_ordem': '00001',
#  'objectid': 2,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1761',
#  'cgn': 1312138,
#  'cod_freg': '13',
#  'cod_gis': '13750100001',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Terramoto forte que provocou queda de pirâmides do '
#                      'extinto convento de S. João Novo (Eremitas Calçados de '
#                      'S. Agostinho)',
#  'dia': 31,
#  'freguesia': 'São Nicolau',
#  'mês': 'Março',
#  'n_o': 13,
#  'n_ordem': '00001',
#  'objectid': 3,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312138,
#  'cod_freg': '13',
#  'cod_gis': '13750100002',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruína da parede Norte da igreja do antigo convento de S. '
#                      'Domingos: "… por causa do terramoto do primeiro de '
#                      'Novembro de 1755 que arruínara a igreja".',
#  'dia': 1,
#  'freguesia': 'São Nicolau',
#  'mês': 'Novembro',
#  'n_o': 6,
#  'n_ordem': '00002',
#  'objectid': 4,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100001',
#  'cod_sgr': '7501',
#  'danos_provocados': 'A  ruína de uma fresta e tabuleiro, duma casa na rua de '
#                      "Sant'ana, junto à antiga capela do mesmo nome.",
#  'dia': 1,
#  'freguesia': 'Sé',
#  'mês': 'Novembro',
#  'n_o': 4,
#  'n_ordem': '00001',
#  'objectid': 5,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100002',
#  'cod_sgr': '7501',
#  'danos_provocados': 'A casa-torre da Câmara ficou em muito mau estado.',
#  'dia': 1,
#  'freguesia': 'Sé',
#  'mês': 'Novembro',
#  'n_o': 8,
#  'n_ordem': '00002',
#  'objectid': 6,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100003',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Queda de pedras da fachada da Sé.',
#  'dia': 1,
#  'freguesia': 'Sé',
#  'mês': 'Novembro',
#  'n_o': 10,
#  'n_ordem': '00003',
#  'objectid': 7,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100004',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruína da capela de São Roque que existia em frente da '
#                      'porta travessa da Sé. ',
#  'dia': 1,
#  'freguesia': 'Sé',
#  'mês': 'Novembro',
#  'n_o': 7,
#  'n_ordem': '00004',
#  'objectid': 8,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1761',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100005',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Terramoto forte que provocou queda de pirâmides da Sé '
#                      'Catedral.',
#  'dia': 31,
#  'freguesia': 'Sé',
#  'mês': 'Março',
#  'n_o': 14,
#  'n_ordem': '00005',
#  'objectid': 9,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312120,
#  'cod_freg': '14',
#  'cod_gis': '14750100006',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruina da fachada e do coro da antiga capela de N. S. da '
#                      'Batalha',
#  'dia': 1,
#  'freguesia': 'Santo Ildefonso',
#  'mês': 'Novembro',
#  'n_o': 5,
#  'n_ordem': '00006',
#  'objectid': 10,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100007',
#  'cod_sgr': '7501',
#  'danos_provocados': '"Em 1834, a torre e a igreja do convento dos Lóios, '
#                      'continuavam de pé. Apesar da torre ter rachado de alto a '
#                      'baixo, por ocasião do terramoto de 1755, ..."',
#  'dia': 1,
#  'freguesia': 'Sé',
#  'mês': 'Novembro',
#  'n_o': 9,
#  'n_ordem': '00007',
#  'objectid': 11,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312154,
#  'cod_freg': '15',
#  'cod_gis': '15750100001',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Uma cruz da capela de Inácio António Coutinho, torceu e '
#                      'mudou de direcção.',
#  'dia': 1,
#  'freguesia': 'Vitória',
#  'mês': 'Novembro',
#  'n_o': 2,
#  'n_ordem': '00001',
#  'objectid': 12,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312154,
#  'cod_freg': '15',
#  'cod_gis': '15750100002',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Queda de uma ameia da porta do Olival e alteração da '
#                      'disposição das ameias da atalaia.',
#  'dia': 1,
#  'freguesia': 'Vitória',
#  'mês': 'Novembro',
#  'n_o': 1,
#  'n_ordem': '00002',
#  'objectid': 13,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1969',
#  'cgn': 1312154,
#  'cod_freg': '15',
#  'cod_gis': '15750100003',
#  'cod_sgr': '7501',
#  'danos_provocados': '"Ruíu a cornija do edifício da Cadeia Civil do Porto. '
#                      'Desprenderam-se da fachada as pedras da cornija '
#                      'superior. Dois grandes blocos que serviam de remate e '
#                      'ornamento à fachada, caíram sobre o passeio…"',
#  'dia': 28,
#  'freguesia': 'Vitória',
#  'mês': 'Fevereiro',
#  'n_o': 35,
#  'n_ordem': '00003',
#  'objectid': 14,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1755',
#  'cgn': 1312154,
#  'cod_freg': '15',
#  'cod_gis': '15750100004',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruína do antigo tribunal e cadeia da Relação.',
#  'dia': 1,
#  'freguesia': 'Vitória',
#  'mês': 'Novembro',
#  'n_o': 11,
#  'n_ordem': '00004',
#  'objectid': 15,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1761',
#  'cgn': 1312154,
#  'cod_freg': '15',
#  'cod_gis': '15750100005',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Terramoto forte que provocou queda de pirâmides do '
#                      'extinto mosteiro de S. Bento da Vitória.',
#  'dia': 31,
#  'freguesia': 'Vitória',
#  'mês': 'Março',
#  'n_o': 12,
#  'n_ordem': '00005',
#  'objectid': 16,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1981',
#  'cgn': 1312073,
#  'cod_freg': '07',
#  'cod_gis': '07750100002',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Campo do Rou nº 25 e 26: O temporal terá contribuído '
#                      'para a derrocada da fachada destes prédios... O '
#                      'deficiente escoramento da fachada não evitou a '
#                      'inclinação da parede de meação entre as duas casas.',
#  'dia': 17,
#  'freguesia': 'Massarelos',
#  'mês': 'Dezembro',
#  'n_o': 41,
#  'n_ordem': '00002',
#  'objectid': 17,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1981',
#  'cgn': 1312073,
#  'cod_freg': '07',
#  'cod_gis': '07750100003',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Rua da Macieirinha nºs 6, 8 e 9: Resvalamento do terreno '
#                      'onde assentam os alicerces destas casas provocou a '
#                      'desconjunção dos soalhos e a abertura de grandes brechas '
#                      'nas paredes das mesmas.',
#  'dia': 17,
#  'freguesia': 'Massarelos',
#  'mês': 'Dezembro',
#  'n_o': 40,
#  'n_ordem': '00003',
#  'objectid': 18,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1990',
#  'cgn': 1312073,
#  'cod_freg': '07',
#  'cod_gis': '07750100004',
#  'cod_sgr': '7501',
#  'danos_provocados': '" Blocos de granito, alguns com várias toneladas, '
#                      'desprenderam-se da escarpa que ladeia a rua da '
#                      'Restauração, abatendo-se sobre a via…"',
#  'dia': 11,
#  'freguesia': 'Massarelos',
#  'mês': 'Agosto',
#  'n_o': 43,
#  'n_ordem': '00004',
#  'objectid': 19,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1947',
#  'cgn': 1312081,
#  'cod_freg': '08',
#  'cod_gis': '08750100002',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Os últimos temporais provocaram a ruína de um grande '
#                      'muro, entre a rua da Restauração e a rua Nova do '
#                      'Palácio, provocando a demolição de um prédio de três '
#                      'andares.',
#  'dia': 22,
#  'freguesia': 'Miragaia',
#  'mês': 'Fevereiro',
#  'n_o': 27,
#  'n_ordem': '00002',
#  'objectid': 20,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1947',
#  'cgn': 1312081,
#  'cod_freg': '08',
#  'cod_gis': '08750100003',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desabamento no nº 56 da rua de S. Pedro de Miragaia, '
#                      'provocado pela infiltração de águas pluviais num terreno '
#                      'situado no lado Norte deste edifício e que causou alguns '
#                      'danos nos prédios adjacentes (nºs 26, 32 e 54).',
#  'dia': 7,
#  'freguesia': 'Miragaia',
#  'mês': 'Fevereiro',
#  'n_o': 28,
#  'n_ordem': '00003',
#  'objectid': 21,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '2000',
#  'cgn': 1312081,
#  'cod_freg': '08',
#  'cod_gis': '08750100004',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Derrocada de dois barrotes no nº 71 da rua Francisco '
#                      'Rocha Soares, devido à infiltração de águas pluviais e '
#                      'ao mau estado de conservação do edifício.',
#  'dia': 29,
#  'freguesia': 'Miragaia',
#  'mês': 'Dezembro',
#  'n_o': 55,
#  'n_ordem': '00004',
#  'objectid': 22,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': 'final do séc. XVIII',
#  'cgn': 1312081,
#  'cod_freg': '08',
#  'cod_gis': '08750100005',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruína e queda do paredão das Virtudes.',
#  'dia': None,
#  'freguesia': 'Miragaia',
#  'mês': None,
#  'n_o': 15,
#  'n_ordem': '00005',
#  'objectid': 23,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1970',
#  'cgn': 1312138,
#  'cod_freg': '13',
#  'cod_gis': '13750100003',
#  'cod_sgr': '7501',
#  'danos_provocados': 'A rocha em que assenta o alicerce do trecho de muralha '
#                      'fernandina, destas escadas, encontra-se em completo '
#                      'estado de desagregação, tendo caído grandes pedaços de '
#                      'rocha, de 13 para 14 de Fevereiro.',
#  'dia': 13,
#  'freguesia': 'São Nicolau',
#  'mês': 'Fevereiro',
#  'n_o': 36,
#  'n_ordem': '00003',
#  'objectid': 24,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1895',
#  'cgn': 1312138,
#  'cod_freg': '13',
#  'cod_gis': '13750100004',
#  'cod_sgr': '7501',
#  'danos_provocados': '"Ontem de manhã, abateu parte do pavimento da rua Nova '
#                      'da Alfândega, em frente ao templo de São Francisco."',
#  'dia': 26,
#  'freguesia': 'São Nicolau',
#  'mês': 'Dezembro',
#  'n_o': 21,
#  'n_ordem': '00004',
#  'objectid': 25,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1992',
#  'cgn': 1312146,
#  'cod_freg': '13',
#  'cod_gis': '13750100005',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Largo do Colégio, 9-12: "… durante trabalhos de '
#                      'consolidação do talude que tinha deslizado sobre alguns '
#                      'edifícios na rua dos Mercadores…"',
#  'dia': None,
#  'freguesia': 'Sé',
#  'mês': 'Setembro',
#  'n_o': 44,
#  'n_ordem': '00005',
#  'objectid': 26,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1983',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100008',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desmoronamento de um muro no largo do Colégio à Sé, que '
#                      'servia de suporte precário de uma entulheira, após as '
#                      'fortes chuvas ocorridas nesse dia .',
#  'dia': 9,
#  'freguesia': 'Sé',
#  'mês': 'Novembro',
#  'n_o': 42,
#  'n_ordem': '00008',
#  'objectid': 27,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '2006',
#  'cgn': 1312138,
#  'cod_freg': '14',
#  'cod_gis': '14750100009',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Queda de pedras da parede granítica e do muro de suporte '
#                      'do largo do Colégio. O desprendimento ocorrido provocou '
#                      'o encerramento das escadas.',
#  'dia': None,
#  'freguesia': 'São Nicolau',
#  'mês': 'Setembro',
#  'n_o': 60,
#  'n_ordem': '00009',
#  'objectid': 28,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1947',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100010',
#  'cod_sgr': '7501',
#  'danos_provocados': '"Devido à infiltração de águas pluviais na rua da '
#                      'Bainharia, em frente ao prédio nº 38, o pavimento aluíu '
#                      'na extensão de 1,5 m de largura com 1,60 m de '
#                      'profundidade."',
#  'dia': 8,
#  'freguesia': 'Sé',
#  'mês': 'Fevereiro',
#  'n_o': 25,
#  'n_ordem': '00010',
#  'objectid': 29,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1997',
#  'cgn': 1312146,
#  'cod_freg': '13',
#  'cod_gis': '13750100006',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desprendimento de três pedras de grande porte ... sobre '
#                      'a escada do Codeçal (junto à ponte Luiz I), provocaram '
#                      'rombo da rede de protecção da escarpa, do gradeamento da '
#                      'escada e tombaram poste de iluminação.',
#  'dia': 11,
#  'freguesia': 'Sé',
#  'mês': 'Janeiro',
#  'n_o': 52,
#  'n_ordem': '00006',
#  'objectid': 30,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1995',
#  'cgn': 1312146,
#  'cod_freg': '13',
#  'cod_gis': '13750100007',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desprendimento de pedras nas escadas do Codeçal, junto à '
#                      'ponte Luiz I. As pedras soltaram-se devido ao entranhar '
#                      'das raízes de árvores nos blocos da escarpa. Outras '
#                      'pedras ameaçam ruína.',
#  'dia': 7,
#  'freguesia': 'Sé',
#  'mês': 'Junho',
#  'n_o': 50,
#  'n_ordem': '00007',
#  'objectid': 31,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1970',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100011',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Rua Senhora das Verdades nº 42: Ruína do prédio, devido '
#                      'ao deprendimento de terras originado pela queda do muro '
#                      'de suporte, voltado a poente. Perigo do seu '
#                      'desmoronamento sobre prédios contíguos.',
#  'dia': 15,
#  'freguesia': 'Sé',
#  'mês': 'Junho',
#  'n_o': 37,
#  'n_ordem': '00011',
#  'objectid': 32,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1895',
#  'cgn': 1312146,
#  'cod_freg': '13',
#  'cod_gis': '13750100008',
#  'cod_sgr': '7501',
#  'danos_provocados': '"Na noite de anteontem para ontem, caíu um trecho de '
#                      'muro da cerca do Paço Episcopal, para o lado das escadas '
#                      'do Barredo."',
#  'dia': 25,
#  'freguesia': 'Sé',
#  'mês': 'Dezembro',
#  'n_o': 22,
#  'n_ordem': '00008',
#  'objectid': 33,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1994',
#  'cgn': 1312146,
#  'cod_freg': '02',
#  'cod_gis': '02750100001',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desprendimento de pedras na escarpa da Corticeira, junto '
#                      'à antiga fábrica de louças que pôs em perigo duas '
#                      'habitações e atolou de pedras a avenida Gustavo Eiffel.',
#  'dia': 12,
#  'freguesia': 'Sé',
#  'mês': 'Janeiro',
#  'n_o': 29,
#  'n_ordem': '00001',
#  'objectid': 34,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1959',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100012',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desprendimento de blocos de granito, sobre os quais se '
#                      'apoiava o paramento Nascente de parte da muralha '
#                      'fernandina, devido a fortes chuvadas. Estes blocos '
#                      'rolando pela escarpa destruíram nove casas da zona dos '
#                      'Guindais.',
#  'dia': 5,
#  'freguesia': 'Sé',
#  'mês': 'Março',
#  'n_o': 33,
#  'n_ordem': '00012',
#  'objectid': 35,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1879',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100013',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desabamento de três prédios na rua dos Guindais, de '
#                      'parte da rua com o muro de vedação (e as suas linguetas '
#                      'inferiores) e da própria casa que assentava sobre a '
#                      'grande rocha (base da encosta).',
#  'dia': 27,
#  'freguesia': 'Sé',
#  'mês': 'Janeiro',
#  'n_o': 17,
#  'n_ordem': '00013',
#  'objectid': 36,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1959',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100014',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Provável infiltração de águas pluviais, provocou o '
#                      'desabamento de parte da muralha fernandina que ruíu '
#                      'sobre um grupo de casas, no nº 41 das Escadas dos '
#                      'Guindais.',
#  'dia': 5,
#  'freguesia': 'Sé',
#  'mês': 'Março',
#  'n_o': 32,
#  'n_ordem': '00014',
#  'objectid': 37,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1947',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100015',
#  'cod_sgr': '7501',
#  'danos_provocados': 'As casas nºs 76, 80 e 82 da rua do Miradouro abriram '
#                      'brechas com mais de um metro de altura e ruíram. A zona '
#                      'referenciada corresponde às traseiras do antigo palácio '
#                      'de Samodães, onde funciona a escola Oliveira Martins.',
#  'dia': 23,
#  'freguesia': 'Sé',
#  'mês': 'Fevereiro',
#  'n_o': 26,
#  'n_ordem': '00015',
#  'objectid': 38,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '2000',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100016',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Derrocada do muro de suporte do Bairro da Tapada, na '
#                      'sequência do deslizamento de terras do dia 7 do corrente '
#                      'mês.',
#  'dia': 8,
#  'freguesia': 'Sé',
#  'mês': 'Dezembro',
#  'n_o': 56,
#  'n_ordem': '00016',
#  'objectid': 39,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1891',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100017',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Registo do anormal movimento do solo e eminente '
#                      'avalanche de rocha granítica na encosta das Fontaínhas '
#                      'que provoca  fendas nos edifícios adjacentes, pondo em '
#                      'risco casas e pessoas.',
#  'dia': None,
#  'freguesia': 'Sé',
#  'mês': 'Abril',
#  'n_o': 20,
#  'n_ordem': '00017',
#  'objectid': 40,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '2000',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100018',
#  'cod_sgr': '7501',
#  'danos_provocados': '" O mau tempo põs em risco de derrocada 50 habitações do '
#                      'Bairro da Tapada. As fendas existentes começaram a '
#                      'aumentar, o muro que sustinha o bairro começou a ruir '
#                      'lentamente e uma casa desabitada ficou totalmente '
#                      'destruída."',
#  'dia': 7,
#  'freguesia': 'Sé',
#  'mês': 'Dezembro',
#  'n_o': 53,
#  'n_ordem': '00018',
#  'objectid': 41,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1992',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100019',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desabamento de 4 enormes blocos rochosos da escarpa dos '
#                      'Guindais que caíram sobre barracos habitados, '
#                      'danificando o nº 69 da avenida Gustavo Eiffel.',
#  'dia': 28,
#  'freguesia': 'Sé',
#  'mês': 'Setembro',
#  'n_o': 45,
#  'n_ordem': '00019',
#  'objectid': 42,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1995',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100020',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Queda de pedras da escarpa sobre o barraco nº 44 na '
#                      'avenida Gustavo Eiffel.',
#  'dia': 13,
#  'freguesia': 'Sé',
#  'mês': 'Julho',
#  'n_o': 51,
#  'n_ordem': '00020',
#  'objectid': 43,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1995',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100021',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruína do nº 36 da Avenida Gustavo Eiffel, na sequência '
#                      'do desprendimento de pedras do cimo da escarpa. O tempo '
#                      'chuvoso provocou o aluimento de terras e a consequente '
#                      'queda dos blocos rochosos.',
#  'dia': 19,
#  'freguesia': 'Sé',
#  'mês': 'Janeiro',
#  'n_o': 49,
#  'n_ordem': '00021',
#  'objectid': 44,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '1994',
#  'cgn': 1312146,
#  'cod_freg': '02',
#  'cod_gis': '02750100002',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Aluimento de terras na escarpa das Fontaínhas junto à '
#                      'rampa da Corticeira, provocou a destruição parcial do '
#                      'muro de protecção dos peões, na avenida Gustavo Eiffel.',
#  'dia': 12,
#  'freguesia': 'Sé',
#  'mês': 'Janeiro',
#  'n_o': 48,
#  'n_ordem': '00002',
#  'objectid': 45,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1992',
#  'cgn': 1312146,
#  'cod_freg': '02',
#  'cod_gis': '02750100003',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Aluimento e cedência de terrenos e consequente derrocada '
#                      'de parte da antiga fábrica de louças na calçada da '
#                      'Corticeira, provocada pela infiltração de águas '
#                      'pluviais.',
#  'dia': 30,
#  'freguesia': 'Sé',
#  'mês': 'Outubro',
#  'n_o': 47,
#  'n_ordem': '00003',
#  'objectid': 46,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1954',
#  'cgn': 1312146,
#  'cod_freg': '02',
#  'cod_gis': '02750100004',
#  'cod_sgr': '7501',
#  'danos_provocados': 'A infiltração de águas pluviais no morro das Fontaínhas, '
#                      'provocou o desprendimento de pesados blocos de granito, '
#                      'que rolando pela escarpa destruíram uns abarracamentos '
#                      'provisórios e dois automóveis, na estrada marginal ao '
#                      'Douro.',
#  'dia': 4,
#  'freguesia': 'Sé',
#  'mês': 'Março',
#  'n_o': 30,
#  'n_ordem': '00004',
#  'objectid': 47,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '2000',
#  'cgn': 1312022,
#  'cod_freg': '02',
#  'cod_gis': '02750100005',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desprendimento de pedras da escarpa que caíram sobre a '
#                      'faixa de rodagem da Avenida Gustavo Eiffel, próximo da '
#                      'ponte do Infante (em construção), devido à infiltração '
#                      'de águas pluviais, causadas pelas fortes chuvas desses '
#                      'dias.',
#  'dia': 28,
#  'freguesia': 'Bonfim',
#  'mês': 'Dezembro',
#  'n_o': 54,
#  'n_ordem': '00005',
#  'objectid': 48,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '2005',
#  'cgn': 1312022,
#  'cod_freg': '02',
#  'cod_gis': '02750100006',
#  'cod_sgr': '7501',
#  'danos_provocados': '"...derrocada parcial de pedras da escarpa das '
#                      'Fontaínhas sobre os terrenos em socalco na zona '
#                      'confinante com o conjunto de anexos abarracados '
#                      'designados por casas 23, 24, 25 e 26... do bairro '
#                      'Nicolau."',
#  'dia': 27,
#  'freguesia': 'Bonfim',
#  'mês': 'Dezembro',
#  'n_o': 59,
#  'n_ordem': '00006',
#  'objectid': 49,
#  'tipo_de_ocorrência': 'Queda de blocos'}
# {'ano': '2001',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100022',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Ruína e derrocada de um muro de uma casa abandonada para '
#                      'a via pública na rua das Fontaínhas, junto à  ponte do '
#                      'Infante (em construção).',
#  'dia': 13,
#  'freguesia': 'Sé',
#  'mês': 'Fevereiro',
#  'n_o': 57,
#  'n_ordem': '00022',
#  'objectid': 50,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1992',
#  'cgn': 1312022,
#  'cod_freg': '02',
#  'cod_gis': '02750100007',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Deslizamento de terras no nº 40 da praça da Alegria, '
#                      'provocado por obras realizadas no local, que soterrou '
#                      'uma pessoa.',
#  'dia': 29,
#  'freguesia': 'Bonfim',
#  'mês': 'Setembro',
#  'n_o': 46,
#  'n_ordem': '00007',
#  'objectid': 51,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1897',
#  'cgn': 1312022,
#  'cod_freg': '02',
#  'cod_gis': '02750100008',
#  'cod_sgr': '7501',
#  'danos_provocados': '"Na madrugada de hontem deu-se um desabamento de terreno '
#                      'na linha urbana, próximo ao tunel do Seminário, ficando '
#                      'a linha interceptada na extensão de uns dez metros, '
#                      'aproximadamente."',
#  'dia': 12,
#  'freguesia': 'Bonfim',
#  'mês': 'Janeiro',
#  'n_o': 24,
#  'n_ordem': '00008',
#  'objectid': 52,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1896',
#  'cgn': 1312022,
#  'cod_freg': '02',
#  'cod_gis': '02750100009',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Uma informação do engenheiro da municipalidade, a '
#                      'respeito de um ofício do senhor Governador Civil, sobre '
#                      'um desabamento ocorrido na encosta do monte do '
#                      'Seminário.',
#  'dia': None,
#  'freguesia': 'Bonfim',
#  'mês': 'Janeiro',
#  'n_o': 23,
#  'n_ordem': '00009',
#  'objectid': 53,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
# {'ano': '1755',
#  'cgn': 1312154,
#  'cod_freg': '15',
#  'cod_gis': '15750100006',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Cedência do aparelho da galilé que sustentava o coro na '
#                      'igreja de São Bento da Vitória.',
#  'dia': 1,
#  'freguesia': 'Vitória',
#  'mês': 'Novembro',
#  'n_o': 61,
#  'n_ordem': '00006',
#  'objectid': 54,
#  'tipo_de_ocorrência': 'Sismo'}
# {'ano': '1851',
#  'cgn': 1312146,
#  'cod_freg': '14',
#  'cod_gis': '14750100023',
#  'cod_sgr': '7501',
#  'danos_provocados': 'Desabamento de uma grande cortina de granito provoca a '
#                      'destruição de algumas casas nos Guindais.',
#  'dia': 29,
#  'freguesia': 'Sé',
#  'mês': 'Janeiro',
#  'n_o': 16,
#  'n_ordem': '00023',
#  'objectid': 55,
#  'tipo_de_ocorrência': 'Deslizamento de terrenos'}
